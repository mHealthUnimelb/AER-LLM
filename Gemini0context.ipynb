# %% [markdown]
# Step 1. Install and import packages

# %%
import textwrap
import csv
import json
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import time
import google.generativeai as genai
import re 

from IPython.display import display
from IPython.display import Markdown
import ast 
import pandas as pd
from collections import Counter
import numpy as np
from scipy.spatial import distance
import os
from pathlib import Path

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY= 'AIzaSyBXOwIFMOC_CJ_1EfgbwYtpWuAvTOvNx90'

genai.configure(api_key=GOOGLE_API_KEY)

model = genai.GenerativeModel('gemini-1.5-flash')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module was compiled against NumPy C-API version 0x10 (NumPy 1.23) but the running NumPy has C-API version 0xf. Check the section C-API incompatibility at the Troubleshooting ImportError section at https://numpy.org/devdocs/user/troubleshooting-importerror.html#c-api-incompatibility for indications on how to solve this problem.

# %% [markdown]
# Step 2. Get the dialog order for all sessions

# %%
def get_dialog_order(tran_path):
    diaglog_ids = []
    for session in range(1,6):
        session = "Session" + str(session)
        session_path = os.path.join(tran_path, session)
        trans_path = os.path.join(session_path, 'dialog/transcriptions')
        trans_lists = sorted(os.listdir(trans_path))
        for i in range(len(trans_lists)):
            full_trans_path = os.path.join(trans_path, trans_lists[i])
            texts = open(full_trans_path, 'r').readlines()
            for text in texts:
                sentence_id = text.split()[0]
                diaglog_ids.append(sentence_id)
    return diaglog_ids
tran_path = './data/IEMOCAP_full_release/'
diaglog_id_orders = get_dialog_order(tran_path)
print("Number of sentence ids across all sessions: ", len(diaglog_id_orders))
# Out:
# Number of sentence ids across all sessions:  10238

# %% [markdown]
# Step 3. Load the data

# %%
file_path = './data/iemocap_ambiguous.json'
data = json.load(open(file_path))
for i in range(len(data)):
    data[i]['speaker'] = data[i]['id'][:5] + data[i]['id'].split("_")[2][0]

# %% [markdown]
# Transfer three ground true labels to distributions

# %%
def get_label_prob(data):

    emo_labels = ['neu', 'hap', 'ang', 'sad']
    emotion_code_dict = {"Neutral state":"neu", "Happiness":"hap", "Anger":"ang", "Sadness":"sad", "Frustration":"others", "Contempt":"others", "Excitement":"others", "Surprise":"others", "Disgust":"others", "Fear":"others", "Other": "others"}
    num_out_labels = 0
    for item in data:
        amb_labels = []
        if item['need_prediction'] == 'yes':
            for emo in item['emotion']:
                amb_labels.append(emotion_code_dict[emo])

            filtered_labels = [label for label in amb_labels if label in emo_labels]
            for label in amb_labels:
                if label not in emo_labels:
                    num_out_labels += 1


            item['amb_emotion'] = filtered_labels

            emotion_counts = Counter(filtered_labels)
            total_count = sum(emotion_counts.values())
            
            probs = {emo: round(emotion_counts[emo]/total_count,2) for emo in emo_labels}
            item['emotion_probs'] = [probs[emo] for emo in emo_labels]

    return data, num_out_labels

new_data, num_out_labels = get_label_prob(data)
print("Number of instances that their emotions are outside four labels: ", num_out_labels)
# Out:
# Number of instances that their emotions are outside four labels:  0

# %% [markdown]
# Rearrange data into sessions:

# %%
# rearrange the data into sessions
def rearrange_data(data):
    session_dict = {}
    for item in data:
        session_impro_id = item['id'][:6]
        if session_impro_id not in session_dict:
            session_dict[session_impro_id] = []
        session_dict[session_impro_id].append(item)
    return session_dict

session_data = rearrange_data(new_data)
print('session in the data')
print(list(session_data.keys()))
print("number of session_improvisations:",len(session_data))
print('--------\na sample entry:')
for key, value in session_data[list(session_data.keys())[0]][0].items():
    print(f"{key}: {value}")
# Out:
# session in the data
# ['Ses01F', 'Ses01M', 'Ses02F', 'Ses02M', 'Ses03F', 'Ses03M', 'Ses04F', 'Ses04M', 'Ses05F', 'Ses05M']
# number of session_improvisations: 10
# --------
# a sample entry:
# id: Ses01F_impro01_F000
# emotion: ['Neutral state', 'Neutral state', 'Neutral state']
# need_prediction: yes
# speaker: Ses01F
# groundtruth: Excuse me.
# audio: IEMOCAP_full_release/Session/1/sentences/wav/Ses01F_impro01_F000/Ses01F_impro01_F000.wav
# amb_emotion: ['neu', 'neu', 'neu']
# emotion_probs: [1.0, 0.0, 0.0, 0.0]

# %% [markdown]
# Reorder data according to dialog ids

# %%
def order_sentences(diaglog_id_orders, new_data):
    order_sen = []
    for sentence_id in diaglog_id_orders:
        for item in new_data:
            if item['id'] == sentence_id:
                order_sen.append(item)
                break
    return order_sen
order_data = order_sentences(diaglog_id_orders, new_data)
print("Number of ordered sentences across all sessions: ", len(order_data))
num_pred = 0
for i in range(len(order_data)):
    if order_data[i]['need_prediction'] == 'yes':
        num_pred += 1
print("Number of sentences that need prediction: ", num_pred)
print("List of first 5 sentence ids in the first sessions: \n", [item['id'] for item in order_data[0:5]])
# Out:
# Number of ordered sentences across all sessions:  10039
# Number of sentences that need prediction:  4370
# List of first 5 sentence ids in the first sessions:
#  ['Ses01F_impro01_F000', 'Ses01F_impro01_M000', 'Ses01F_impro01_F001', 'Ses01F_impro01_M001', 'Ses01F_impro01_F002']

# %%
def match_features(index, order_audio_data):
    matched_features = {}
    if 'egemaps' not in order_audio_data[index]:
        print("Error occurred: No egemaps in the audio data, the index is ", index)
    else:
        egemaps = order_audio_data[index]['egemaps']
        column_names = egemaps.columns
        values = egemaps.values[0]
        for col_id in range(len(column_names)):
            matched_features[column_names[col_id]] = float(values[col_id])
        return matched_features

# %%
len(order_data)
# Out:
# 10039

# %% [markdown]
# Step 3. Create an emotion predictor that takes context and spoken text as input and output an emotion label (what you need to modify).

# %%
def Gemini_emotion_predictor(cur_sentence):
    """
    Predicts the emotional state of a speaker based on the current input sentence and the conversational context.

    Parameters:
    context (list of dict): A list of dictionaries, each representing a previous conversational turn. Each dictionary
                            should contain at least the keys 'speaker' and 'sentence' indicating who the speaker was
                            and what they said, respectively.
    cur_input (dict): A dictionary representing the current sentence to be analyzed. It should contain at least the keys
                        'speaker' and 'sentence', similar to the dictionaries in `context`.
    number_of_contexts (int, optional): The number of contextual entries to consider for emotion prediction. Defaults to 3. The more context, the more expensive.

    Returns:
    str: The predicted emotion for the current sentence, from a set of predefined emotions such as 'happy', 'sad',
            'neutral', or 'angry'.
    """
    task = f"Predict the probability of the emotion of the sentence from the options [neutral, happy, angry, sad]. The sentence is '{cur_sentence['groundtruth']}'. Output statisfies the following rules.\n"
    task_req1 = "Rule 1: Generate a dictionary of emotion probabilities in format of {'neutral': 0.1, 'happy':0.0, 'angry':0.1, 'sad':0.8}. If you think there is only one emotion in the sentence, then give the probability to 1.\n "
    task_req2 = "Rule 2: Ensure the sum of probability equal to 1.\n"
    task_amb2 = "Rule 3: Do not explain, only the dictionary.\n"
    task_final = "Please check again whether your output follows the three rules."
    prompt = task + task_req1 + task_req2 + task_amb2 + task_final
    # print(prompt)
    response = model.generate_content(prompt)
    return response, prompt

# %%
r, p = Gemini_emotion_predictor(order_data[0])
r.text
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725759278.544829 16976474 config.cc:230] gRPC experiments enabled: call_status_override_on_cancellation, event_engine_dns, event_engine_listener, http2_stats_fix, monitoring_experiment, pick_first_new, trace_record_callops, work_serializer_clears_time_cache
# I0000 00:00:1725759278.561662 16976474 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# "```json\n{'neutral': 1.0, 'happy': 0.0, 'angry': 0.0, 'sad': 0.0}\n```"

# %% [markdown]
# Step 4. Predict the entire session and output a sequence of emotion prediction for each sentence that requires a prediction.

# %%
# transfer response from ```json\n{'neutral': 0.0, 'happy': 0.0, 'angry': 0.0, 'sad': 1.0}\n```
def identify_format(text):
    match = re.search(r"\{.*\}", text)
    if match:
        text = match.group(0)
    result_dict = ast.literal_eval(text)
    return result_dict
def dictToList(dict, emo_labels):
    prob_list = [dict[emo] for emo in emo_labels]
    return prob_list

# %%
log = {}
def predict_sentence(index_sentence, data):
    error = False
    emo_labels = ['neutral', 'happy', 'angry', 'sad']
    cur_sentence = data[index_sentence]
    cur_label = cur_sentence['emotion_probs']

    try:
        time.sleep(0.2)
        response,prompt = Gemini_emotion_predictor(cur_sentence)
        response = response.text.strip()

        # input both context and the current sentence to the emotion predictor
        try:
            clear_response = identify_format(response)
            cur_pred = dictToList(clear_response, emo_labels)
            log[cur_sentence["id"]] = [prompt, response]
        except:
            # if there is an error, fill a neutral to keep the output of same dimension
            print('Gemini response is not in the right format: ', response, cur_sentence['id'])
            cur_pred = [1.0,0.0,0.0,0.0]
            error = True
            log[cur_sentence["id"]] = ["Response not in the right format", prompt, response]
    except:
        try: 
            time.sleep(30)
            response,prompt = Gemini_emotion_predictor(cur_sentence)
            response = response.text.strip()

            # input both context and the current sentence to the emotion predictor
            try:
                clear_response = identify_format(response)
                cur_pred = dictToList(clear_response, emo_labels)
                log[cur_sentence["id"]] = [prompt, response]
            except:
                # if there is an error, fill a neutral to keep the output of same dimension
                print('Gemini response is not in the right format: ', response, cur_sentence['id'])
                cur_pred = [1.0,0.0,0.0,0.0]
                error = True
                log[cur_sentence["id"]] = ["Response not in the right format", prompt, response]

        except:
            print('Gemini api has an error.: ', cur_sentence)
            cur_pred = [1.0,0.0,0.0,0.0]
            error = True
            log[cur_sentence["id"]] = ["Gemini api has an error."]

    return cur_label, cur_pred, error

# %%
log = {}
def make_predictions(data):
    number_errors, number_success = 0, 0
    started_sessions = []
    all_ground_truth, all_pred = [], []

    for i, item in enumerate(data):
        
        if item['id'][:-4] not in started_sessions:
            started_sessions.append(item['id'][:-4])
            print("Session ", item['id'][:-4])
            
        if item["need_prediction"] == "yes":
            label, prediction, error = predict_sentence(i, order_data)
            all_ground_truth.append(label)
            all_pred.append(prediction)
            if error == True:
                number_errors += 1
            else: 
                number_success += 1

        if i == len(order_data)-1 or order_data[i+1]['id'][:-4] != order_data[i]['id'][:-4]:
            print('Number of error counts:', number_errors, "; Number of predictions:", number_success)
            number_errors, number_success = 0, 0
            print('------------------------')
        # for testing
        # if i > 20:
        #     break
    return all_pred, all_ground_truth

# %%
all_pred, all_ground_truth = make_predictions(order_data)
# Out:
# Session  Ses01F_impro01_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses01F_impro02_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses01F_impro03_
# Gemini response is not in the right format:  Please provide me with the sentence so I can predict the emotion probabilities. Ses01F_impro03_F003
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01F_impro03_F013
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses01F_impro03_M013
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to determine the emotion probabilities. Ses01F_impro03_F026
# Number of error counts: 4 ; Number of predictions: 37
# ------------------------
# Session  Ses01F_impro04_
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Session  Ses01F_impro05_
# Number of error counts: 0 ; Number of predictions: 22
# ------------------------
# Session  Ses01F_impro06_
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to determine the emotion probabilities. Ses01F_impro06_F017
# Number of error counts: 1 ; Number of predictions: 44
# ------------------------
# Session  Ses01F_impro07_
# Gemini response is not in the right format:  Please provide me with the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses01F_impro07_M002
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01F_impro07_F010
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01F_impro07_F015
# Number of error counts: 3 ; Number of predictions: 33
# ------------------------
# Session  Ses01F_script01_1_
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Session  Ses01F_script01_2_
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Session  Ses01F_script01_3_
# Gemini response is not in the right format:  Please provide me with the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01F_script01_3_F010
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses01F_script01_3_F011
# Gemini response is not in the right format:  Please provide me with the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01F_script01_3_F012
# Number of error counts: 3 ; Number of predictions: 48
# ------------------------
# Session  Ses01F_script02_1_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses01F_script02_2_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01F_script02_2_M043
# Gemini response is not in the right format:  Please provide me with the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01F_script02_2_M046
# Number of error counts: 2 ; Number of predictions: 32
# ------------------------
# Session  Ses01F_script03_1_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01F_script03_1_F020
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01F_script03_1_M036
# Number of error counts: 2 ; Number of predictions: 34
# ------------------------
# Session  Ses01F_script03_2_
# Number of error counts: 0 ; Number of predictions: 28
# ------------------------
# Session  Ses01M_impro01_
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Session  Ses01M_impro02_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses01M_impro03_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01M_impro03_M011
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses01M_impro03_F016
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01M_impro03_M023
# Number of error counts: 3 ; Number of predictions: 43
# ------------------------
# Session  Ses01M_impro04_
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Session  Ses01M_impro05_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses01M_impro06_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01M_impro06_F017
# Number of error counts: 1 ; Number of predictions: 58
# ------------------------
# Session  Ses01M_impro07_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01M_impro07_M011
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01M_impro07_M020
# Gemini response is not in the right format:  Please provide the sentence so I can predict the emotion probabilities. Ses01M_impro07_M030
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01M_impro07_F034
# Number of error counts: 4 ; Number of predictions: 46
# ------------------------
# Session  Ses01M_script01_1_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses01M_script01_2_
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Session  Ses01M_script01_3_
# Number of error counts: 0 ; Number of predictions: 54
# ------------------------
# Session  Ses01M_script02_1_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses01M_script02_2_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses01M_script03_1_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01M_script03_1_F010
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to determine the emotion probabilities. Ses01M_script03_1_M028
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01M_script03_1_F036
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses01M_script03_1_F039
# Number of error counts: 4 ; Number of predictions: 46
# ------------------------
# Session  Ses01M_script03_2_
# Number of error counts: 0 ; Number of predictions: 41
# ------------------------
# Session  Ses02F_impro01_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses02F_impro02_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses02F_impro03_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses02F_impro03_F003
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses02F_impro03_F022
# Gemini response is not in the right format:  Please provide the sentence so I can predict the emotion probabilities. Ses02F_impro03_M019
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses02F_impro03_M025
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses02F_impro03_F030
# Number of error counts: 5 ; Number of predictions: 46
# ------------------------
# Session  Ses02F_impro04_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses02F_impro05_
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Session  Ses02F_impro06_
# Number of error counts: 0 ; Number of predictions: 33
# ------------------------
# Session  Ses02F_impro07_
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses02F_impro07_M010
# Gemini response is not in the right format:  Please provide me with the sentence so I can predict the emotion probability. Ses02F_impro07_M022
# Gemini response is not in the right format:  Please provide me with the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses02F_impro07_M027
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses02F_impro07_F029
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses02F_impro07_F031
# Number of error counts: 5 ; Number of predictions: 65
# ------------------------
# Session  Ses02F_impro08_
# Number of error counts: 0 ; Number of predictions: 41
# ------------------------
# Session  Ses02F_script01_1_
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Session  Ses02F_script01_2_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses02F_script01_3_
# Number of error counts: 0 ; Number of predictions: 39
# ------------------------
# Session  Ses02F_script02_1_
# Number of error counts: 0 ; Number of predictions: 28
# ------------------------
# Session  Ses02F_script02_2_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses02F_script03_1_
# Number of error counts: 0 ; Number of predictions: 52
# ------------------------
# Session  Ses02F_script03_2_
# Number of error counts: 0 ; Number of predictions: 20
# ------------------------
# Session  Ses02M_impro01_
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Session  Ses02M_impro02_
# Number of error counts: 0 ; Number of predictions: 13
# ------------------------
# Session  Ses02M_impro03_
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses02M_impro03_M003
# Gemini response is not in the right format:  Please provide me with the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses02M_impro03_F015
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses02M_impro03_M019
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses02M_impro03_F022
# Number of error counts: 4 ; Number of predictions: 46
# ------------------------
# Session  Ses02M_impro04_
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Session  Ses02M_impro05_
# Number of error counts: 0 ; Number of predictions: 22
# ------------------------
# Session  Ses02M_impro06_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses02M_impro06_M010
# Number of error counts: 1 ; Number of predictions: 39
# ------------------------
# Session  Ses02M_impro07_
# Gemini response is not in the right format:  Please provide me with the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses02M_impro07_M015
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses02M_impro07_F013
# Gemini response is not in the right format:  Please provide me with the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses02M_impro07_M029
# Number of error counts: 3 ; Number of predictions: 58
# ------------------------
# Session  Ses02M_impro08_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses02M_script01_1_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses02M_script01_2_
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Session  Ses02M_script01_3_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses02M_script02_1_
# Number of error counts: 0 ; Number of predictions: 24
# ------------------------
# Session  Ses02M_script02_2_
# Number of error counts: 0 ; Number of predictions: 33
# ------------------------
# Session  Ses02M_script03_1_
# Number of error counts: 0 ; Number of predictions: 39
# ------------------------
# Session  Ses02M_script03_2_
# Number of error counts: 0 ; Number of predictions: 25
# ------------------------
# Session  Ses03F_impro01_
# Number of error counts: 0 ; Number of predictions: 0
# ------------------------
# Session  Ses03F_impro02_
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Session  Ses03F_impro03_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses03F_impro03_M001
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses03F_impro03_M005
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses03F_impro03_M012
# Gemini response is not in the right format:  Please provide me with the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses03F_impro03_F024
# Number of error counts: 4 ; Number of predictions: 36
# ------------------------
# Session  Ses03F_impro04_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses03F_impro05_
# Number of error counts: 0 ; Number of predictions: 0
# ------------------------
# Session  Ses03F_impro06_
# Number of error counts: 0 ; Number of predictions: 53
# ------------------------
# Session  Ses03F_impro07_
# Number of error counts: 0 ; Number of predictions: 58
# ------------------------
# Session  Ses03F_impro08_
# Gemini response is not in the right format:  Please provide me with the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses03F_impro08_F001
# Number of error counts: 1 ; Number of predictions: 17
# ------------------------
# Session  Ses03F_script01_1_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses03F_script01_2_
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Session  Ses03F_script01_3_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses03F_script02_1_
# Number of error counts: 0 ; Number of predictions: 23
# ------------------------
# Session  Ses03F_script02_2_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses03F_script03_1_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses03F_script03_1_F000
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses03F_script03_1_F024
# Gemini response is not in the right format:  Please provide me with the sentence so I can predict the emotion probabilities! Ses03F_script03_1_F026
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses03F_script03_1_M029
# Number of error counts: 4 ; Number of predictions: 41
# ------------------------
# Session  Ses03F_script03_2_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses03M_impro01_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses03M_impro02_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses03M_impro03_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses03M_impro03_M005
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses03M_impro03_F019
# Number of error counts: 2 ; Number of predictions: 69
# ------------------------
# Session  Ses03M_impro04_
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Session  Ses03M_impro05a_
# Number of error counts: 0 ; Number of predictions: 22
# ------------------------
# Session  Ses03M_impro05b_
# Number of error counts: 0 ; Number of predictions: 28
# ------------------------
# Session  Ses03M_impro06_
# Number of error counts: 0 ; Number of predictions: 47
# ------------------------
# Session  Ses03M_impro07_
# Number of error counts: 0 ; Number of predictions: 46
# ------------------------
# Session  Ses03M_impro08a_
# Number of error counts: 0 ; Number of predictions: 13
# ------------------------
# Session  Ses03M_impro08b_
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Session  Ses03M_script01_1_
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Session  Ses03M_script01_2_
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Session  Ses03M_script01_3_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses03M_script02_1_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses03M_script02_2_
# Number of error counts: 0 ; Number of predictions: 33
# ------------------------
# Session  Ses03M_script03_1_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses03M_script03_1_M036
# Number of error counts: 1 ; Number of predictions: 57
# ------------------------
# Session  Ses03M_script03_2_
# Number of error counts: 0 ; Number of predictions: 24
# ------------------------
# Session  Ses04F_impro01_
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Session  Ses04F_impro02_
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Session  Ses04F_impro03_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to determine the emotion probabilities. Ses04F_impro03_F005
# Gemini response is not in the right format:  Please provide me with the sentence so I can predict the emotion probabilities. Ses04F_impro03_F006
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses04F_impro03_F009
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses04F_impro03_F052
# Number of error counts: 4 ; Number of predictions: 72
# ------------------------
# Session  Ses04F_impro04_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses04F_impro05_
# Number of error counts: 0 ; Number of predictions: 11
# ------------------------
# Session  Ses04F_impro06_
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses04F_impro06_F009
# Number of error counts: 1 ; Number of predictions: 22
# ------------------------
# Session  Ses04F_impro07_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses04F_impro07_F004
# Gemini response is not in the right format:  Please provide me with the sentence so I can analyze it and provide you with the emotion probabilities. Ses04F_impro07_F006
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probability. Ses04F_impro07_F021
# Gemini response is not in the right format:  Please provide me with the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses04F_impro07_F030
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses04F_impro07_F036
# Gemini response is not in the right format:  Please provide me with the sentence you want me to analyze. I need the sentence to be able to predict the emotion probabilities. Ses04F_impro07_F064
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses04F_impro07_M068
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses04F_impro07_M069
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses04F_impro07_F065
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses04F_impro07_F078
# Number of error counts: 10 ; Number of predictions: 147
# ------------------------
# Session  Ses04F_impro08_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses04F_script01_1_
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Session  Ses04F_script01_2_
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Session  Ses04F_script01_3_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses04F_script02_1_
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Session  Ses04F_script02_2_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses04F_script03_1_
# Number of error counts: 0 ; Number of predictions: 53
# ------------------------
# Session  Ses04F_script03_2_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses04M_impro01_
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Session  Ses04M_impro02_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses04M_impro03_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses04M_impro03_F008
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses04M_impro03_F016
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses04M_impro03_F022
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses04M_impro03_F024
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses04M_impro03_F025
# Number of error counts: 5 ; Number of predictions: 48
# ------------------------
# Session  Ses04M_impro04_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses04M_impro05_
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Session  Ses04M_impro06_
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Session  Ses04M_impro07_
# Gemini response is not in the right format:  Please provide me with the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses04M_impro07_M013
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses04M_impro07_F016
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses04M_impro07_F027
# Number of error counts: 3 ; Number of predictions: 68
# ------------------------
# Session  Ses04M_impro08_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses04M_script01_1_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses04M_script01_2_
# Number of error counts: 0 ; Number of predictions: 19
# ------------------------
# Session  Ses04M_script01_3_
# Number of error counts: 0 ; Number of predictions: 28
# ------------------------
# Session  Ses04M_script02_1_
# Number of error counts: 0 ; Number of predictions: 19
# ------------------------
# Session  Ses04M_script02_2_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses04M_script03_1_
# Number of error counts: 0 ; Number of predictions: 44
# ------------------------
# Session  Ses04M_script03_2_
# Number of error counts: 0 ; Number of predictions: 45
# ------------------------
# Session  Ses05F_impro01_
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Session  Ses05F_impro02_
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Session  Ses05F_impro03_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses05F_impro03_F006
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses05F_impro03_M035
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses05F_impro03_F036
# Gemini response is not in the right format:  Please provide me with the sentence so I can predict the emotion probabilities. Ses05F_impro03_M038
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses05F_impro03_M043
# Gemini response is not in the right format:  Please provide the sentence so I can predict the emotion probabilities. Ses05F_impro03_F041
# Gemini response is not in the right format:  Please provide me with the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses05F_impro03_M054
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses05F_impro03_M060
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses05F_impro03_F060
# Number of error counts: 9 ; Number of predictions: 112
# ------------------------
# Session  Ses05F_impro04_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses05F_impro05_
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Session  Ses05F_impro06_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses05F_impro06_F004
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses05F_impro06_F015
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses05F_impro06_F024
# Gemini response is not in the right format:  Please provide me with the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses05F_impro06_F027
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses05F_impro06_F028
# Number of error counts: 5 ; Number of predictions: 47
# ------------------------
# Session  Ses05F_impro07_
# Gemini response is not in the right format:  Please provide the sentence you would like me to analyze. I need the sentence to predict the emotion probabilities. Ses05F_impro07_F033
# Gemini response is not in the right format:  Please provide me with the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses05F_impro07_M036
# Number of error counts: 2 ; Number of predictions: 73
# ------------------------
# Session  Ses05F_impro08_
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Session  Ses05F_script01_1_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses05F_script01_2_
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Session  Ses05F_script01_3_
# Number of error counts: 0 ; Number of predictions: 41
# ------------------------
# Session  Ses05F_script02_1_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses05F_script02_2_
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Session  Ses05F_script03_1_
# Number of error counts: 0 ; Number of predictions: 46
# ------------------------
# Session  Ses05F_script03_2_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses05M_impro01_
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Session  Ses05M_impro02_
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Session  Ses05M_impro03_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses05M_impro03_F012
# Number of error counts: 1 ; Number of predictions: 57
# ------------------------
# Session  Ses05M_impro04_
# Gemini response is not in the right format:  Please provide the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses05M_impro04_F013
# Number of error counts: 1 ; Number of predictions: 18
# ------------------------
# Session  Ses05M_impro05_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses05M_impro06_
# Number of error counts: 0 ; Number of predictions: 20
# ------------------------
# Session  Ses05M_impro07_
# Gemini response is not in the right format:  Please provide me with the sentence you want me to analyze. I need the sentence to predict the emotion probabilities. Ses05M_impro07_F012
# Number of error counts: 1 ; Number of predictions: 89
# ------------------------
# Session  Ses05M_impro08_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses05M_script01_1_
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Session  Ses05M_script01_1b_
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Session  Ses05M_script01_2_
# Number of error counts: 0 ; Number of predictions: 13
# ------------------------
# Session  Ses05M_script01_3_
# Number of error counts: 0 ; Number of predictions: 32
# ------------------------
# Session  Ses05M_script02_1_
# Gemini response is not in the right format:  Please provide the sentence so I can predict the emotion probabilities. Ses05M_script02_1_M008
# Number of error counts: 1 ; Number of predictions: 15
# ------------------------
# Session  Ses05M_script02_2_
# Number of error counts: 0 ; Number of predictions: 32
# ------------------------
# Session  Ses05M_script03_1_
# Number of error counts: 0 ; Number of predictions: 60
# ------------------------
# Session  Ses05M_script03_2_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------

# %%
folder_path = "0907_ct0"
print("Total predictions: ", len(all_pred), "Total ground truth:", len(all_ground_truth))
# Write to a CSV file using a context manager
with open(f'./prediction/{folder_path}/pred.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(all_pred)

with open(f'./prediction/{folder_path}/truth.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(all_ground_truth)

json.dump(log, open(f'./prediction/{folder_path}/log.json', 'w'), indent=4)
# Out:
# Total predictions:  4370 Total ground truth: 4370

# %%
log['Ses05M_script02_1_M008']
# Out:
# ['Response not in the right format',
#  "Predict the probability of the emotion of the sentence from the options [neutral, happy, angry, sad]. The sentence is ''. Output statisfies the following rules.\nRule 1: Generate a dictionary of emotion probabilities in format of {'neutral': 0.1, 'happy':0.0, 'angry':0.1, 'sad':0.8}. If you think there is only one emotion in the sentence, then give the probability to 1.\n Rule 2: Ensure the sum of probability equal to 1.\nRule 3: Do not explain, only the dictionary.\nPlease check again whether your output follows the three rules.",
#  'Please provide the sentence so I can predict the emotion probabilities.']

# %%
for i in range(len(order_data)):
    if order_data[i]['id'] == 'Ses05M_script02_1_M008':
        print(order_data[i])
# Out:
# {'id': 'Ses05M_script02_1_M008', 'emotion': ['Happiness', 'Happiness', 'Happiness'], 'need_prediction': 'yes', 'speaker': 'Ses051', 'groundtruth': '', 'amb_emotion': ['hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0]}

# %%
order_data[0]
# Out:
# {'id': 'Ses01F_impro01_F000',
#  'emotion': ['Neutral state', 'Neutral state', 'Neutral state'],
#  'need_prediction': 'yes',
#  'speaker': 'Ses01F',
#  'groundtruth': 'Excuse me.',
#  'audio': 'IEMOCAP_full_release/Session/1/sentences/wav/Ses01F_impro01_F000/Ses01F_impro01_F000.wav',
#  'amb_emotion': ['neu', 'neu', 'neu'],
#  'emotion_probs': [1.0, 0.0, 0.0, 0.0]}
