# %% [markdown]
# Step 1. Install and import packages

# %%
import textwrap
import csv
import json
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import time
import google.generativeai as genai
import re 

from IPython.display import display
from IPython.display import Markdown
import ast 
import pandas as pd
from collections import Counter
import numpy as np
from scipy.spatial import distance
import os
from pathlib import Path

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY= 'AIzaSyDjbwmKkCKl_f-durMYdtpbHasZRpuUHAs'

genai.configure(api_key=GOOGLE_API_KEY)

model = genai.GenerativeModel('gemini-1.5-flash')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module was compiled against NumPy C-API version 0x10 (NumPy 1.23) but the running NumPy has C-API version 0xf. Check the section C-API incompatibility at the Troubleshooting ImportError section at https://numpy.org/devdocs/user/troubleshooting-importerror.html#c-api-incompatibility for indications on how to solve this problem.

# %% [markdown]
# Step 2. Get the dialog order for all sessions

# %%
msp = json.load(open('./data/msp_ambigous.json'))
msp[0]
# Out:
# {'id': 'MSP-PODCAST_0001_0008',
#  'need_prediction': 'no',
#  'emotion': ['Neutral', 'Neutral', 'Sad', 'Other-Inquisitive', 'Neutral'],
#  'groundtruth': ["it's it follows. that's the movie. and i know it came out january 27th in the uk. did it come out later there, or...?"],
#  'audio': 'Audio/MSP-PODCAST_0001_0008.wav',
#  'speaker': '0001'}

# %%
len(msp)
# Out:
# 104267

# %%
index = []
for i in range(len(msp)):
    if msp[i]['need_prediction'] == 'yes':
        index.append(i)
len(index)
# Out:
# 4114

# %%
import pickle

with open('./data/msp_egemaps.pkl', 'rb') as f:
    audio_df = pickle.load(f)

#selected_audio_df = {ID: audio_df[ID] for ID in index}
selected_audio_df = [audio_df[ID] for ID in index]

# %%
descriptions = [

    "Average Fundamental Frequency in Semitones from 27.5 Hz",

    "Normalized Standard Deviation of Fundamental Frequency in Semitones from 27.5 Hz",

    "20th Percentile of Fundamental Frequency in Semitones from 27.5 Hz",

    "50th Percentile (Median) of Fundamental Frequency in Semitones from 27.5 Hz",

    "80th Percentile of Fundamental Frequency in Semitones from 27.5 Hz",

    "Range of Fundamental Frequency in Semitones from 0th to 2nd Percentile",

    "Mean Slope of Rising Fundamental Frequency in Semitones",

    "Standard Deviation of Rising Slopes of Fundamental Frequency in Semitones",

    "Mean Slope of Falling Fundamental Frequency in Semitones",

    "Standard Deviation of Falling Slopes of Fundamental Frequency in Semitones",

    "Average Loudness",

    "Normalized Standard Deviation of Loudness",

    "20th Percentile of Loudness",

    "50th Percentile (Median) of Loudness",

    "80th Percentile of Loudness",

    "Range of Loudness from 0th to 2nd Percentile",

    "Mean Slope of Rising Loudness",

    "Standard Deviation of Rising Slopes of Loudness",

    "Mean Slope of Falling Loudness",

    "Standard Deviation of Falling Slopes of Loudness",

    "Average Spectral Flux",

    "Normalized Standard Deviation of Spectral Flux",

    "Average Mel-Frequency Cepstral Coefficient 1",

    "Normalized Standard Deviation of Mel-Frequency Cepstral Coefficient 1",

    "Average Mel-Frequency Cepstral Coefficient 2",

    "Normalized Standard Deviation of Mel-Frequency Cepstral Coefficient 2",

    "Average Mel-Frequency Cepstral Coefficient 3",

    "Normalized Standard Deviation of Mel-Frequency Cepstral Coefficient 3",

    "Average Mel-Frequency Cepstral Coefficient 4",

    "Normalized Standard Deviation of Mel-Frequency Cepstral Coefficient 4",

    "Average Jitter Local",

    "Normalized Standard Deviation of Jitter Local",

    "Average Local Shimmer in Decibels",

    "Normalized Standard Deviation of Local Shimmer in Decibels",

    "Average Harmonics-to-Noise Ratio in Decibels",

    "Normalized Standard Deviation of Harmonics-to-Noise Ratio in Decibels",

    "Average Logarithmic Ratio of Harmonics H1 to H2",

    "Normalized Standard Deviation of Logarithmic Ratio of Harmonics H1 to H2",

    "Average Logarithmic Ratio of Harmonics H1 to A3",

    "Normalized Standard Deviation of Logarithmic Ratio of Harmonics H1 to A3",

    "Average Frequency of the First Formant",

    "Normalized Standard Deviation of the Frequency of the First Formant",

    "Average Bandwidth of the First Formant",

    "Normalized Standard Deviation of the Bandwidth of the First Formant",

    "Average Logarithmic Amplitude of the First Formant Relative to Fundamental Frequency",

    "Normalized Standard Deviation of the Amplitude of the First Formant Relative to Fundamental Frequency",

    "Average Frequency of the Second Formant",

    "Normalized Standard Deviation of the Frequency of the Second Formant",

    "Average Bandwidth of the Second Formant",

    "Normalized Standard Deviation of the Bandwidth of the Second Formant",

    "Average Logarithmic Amplitude of the Second Formant Relative to Fundamental Frequency",

    "Normalized Standard Deviation of the Amplitude of the Second Formant Relative to Fundamental Frequency",

    "Average Frequency of the Third Formant",

    "Normalized Standard Deviation of the Frequency of the Third Formant",

    "Average Bandwidth of the Third Formant",

    "Normalized Standard Deviation of the Bandwidth of the Third Formant",

    "Average Logarithmic Amplitude of the Third Formant Relative to Fundamental Frequency",

    "Normalized Standard Deviation of the Amplitude of the Third Formant Relative to Fundamental Frequency",

    "Average Alpha Ratio for Voiced Sounds",

    "Normalized Standard Deviation of Alpha Ratio for Voiced Sounds",

    "Average Hammarberg Index for Voiced Sounds",

    "Normalized Standard Deviation of Hammarberg Index for Voiced Sounds",

    "Average Spectral Slope between 0 and 500 Hz for Voiced Sounds",

    "Normalized Standard Deviation of Spectral Slope between 0 and 500 Hz for Voiced Sounds",

    "Average Spectral Slope between 500 and 1500 Hz for Voiced Sounds",

    "Normalized Standard Deviation of Spectral Slope between 500 and 1500 Hz for Voiced Sounds",

    "Average Spectral Flux for Voiced Sounds",

    "Normalized Standard Deviation of Spectral Flux for Voiced Sounds",

    "Average Mel-Frequency Cepstral Coefficient 1 for Voiced Sounds",

    "Normalized Standard Deviation of Mel-Frequency Cepstral Coefficient 1 for Voiced Sounds",

    "Average Mel-Frequency Cepstral Coefficient 2 for Voiced Sounds",

    "Normalized Standard Deviation of Mel-Frequency Cepstral Coefficient 2 for Voiced Sounds",

    "Average Mel-Frequency Cepstral Coefficient 3 for Voiced Sounds",

    "Normalized Standard Deviation of Mel-Frequency Cepstral Coefficient 3 for Voiced Sounds",

    "Average Mel-Frequency Cepstral Coefficient 4 for Voiced Sounds",

    "Normalized Standard Deviation of Mel-Frequency Cepstral Coefficient 4 for Voiced Sounds",

    "Average Alpha Ratio for Unvoiced Sounds",

    "Average Hammarberg Index for Unvoiced Sounds",

    "Average Spectral Slope between 0 and 500 Hz for Unvoiced Sounds",

    "Average Spectral Slope between 500 and 1500 Hz for Unvoiced Sounds",

    "Average Spectral Flux for Unvoiced Sounds",

    "Peaks per Second in Loudness",

    "Voiced Segments Per Second",

    "Average Length of Voiced Segments",

    "Standard Deviation of the Length of Voiced Segments",

    "Average Length of Unvoiced Segments",

    "Standard Deviation of the Length of Unvoiced Segments",

    "Equivalent Continuous Sound Level in Decibels"

]

# %%
def match_features(index, selected_audio_df):
    matched_features = {}
    egemaps = selected_audio_df[index]["egemaps"]
    values = egemaps.values[0]
    for col_id in range(len(descriptions)):
        matched_features[descriptions[col_id]] = float(values[col_id])
    return matched_features

# %%
def get_label_prob(data):

    emo_labels = ['neu', 'hap', 'ang', 'sad']
    emotion_code_dict = {"Neutral":"neu", "Happy":"hap", "Angry":"ang", "Sad":"sad", "Frustration":"others", "Contempt":"others", "Excitement":"others", "Surprise":"others", "Disgust":"others", "Fear":"others", "Other": "others"}
    num_out_labels = 0
    for item in data:
        amb_labels = []
        if item['need_prediction'] == 'yes':
            for emo in item['emotion']:
                amb_labels.append(emotion_code_dict[emo])

            filtered_labels = [label for label in amb_labels if label in emo_labels]
            for label in amb_labels:
                if label not in emo_labels:
                    num_out_labels += 1


            item['amb_emotion'] = filtered_labels

            emotion_counts = Counter(filtered_labels)
            total_count = sum(emotion_counts.values())
            
            probs = {emo: round(emotion_counts[emo]/total_count,2) for emo in emo_labels}
            item['emotion_probs'] = [probs[emo] for emo in emo_labels]

    return data, num_out_labels

msp, num_out_labels = get_label_prob(msp)
print("Number of instances that their emotions are outside four labels: ", num_out_labels)
msp[5]
# Out:
# Number of instances that their emotions are outside four labels:  0
# {'id': 'MSP-PODCAST_0001_0019',
#  'need_prediction': 'yes',
#  'emotion': ['Happy', 'Happy', 'Neutral', 'Neutral', 'Happy'],
#  'groundtruth': ["can't. i had someone in my media studies department, my degree, which was associated with the film production."],
#  'audio': 'Audio/MSP-PODCAST_0001_0019.wav',
#  'speaker': '0001',
#  'amb_emotion': ['hap', 'hap', 'neu', 'neu', 'hap'],
#  'emotion_probs': [0.4, 0.6, 0.0, 0.0]}

# %%
def get_label_dict(data):
    for i in range(len(data)):
        item = data[i]
        if "emotion" in item.keys():
            emotion_counts = Counter(item['emotion'])
            total_count = sum(emotion_counts.values())
            probs = {emo: round(emotion_counts[emo]/total_count,2) for emo in emotion_counts}
            item['emotion_dict'] = probs
        else:
            item['emotion_dict'] = None
    return data

msp = get_label_dict(msp)

# %%
started_sessions = []
organ_msp = {}
for i in range(len(msp)):
    podcast_ID = "_".join(msp[i]['id'].split("_")[0:2])
    if podcast_ID not in started_sessions:
        started_sessions.append("_".join(msp[i]['id'].split("_")[0:2]))
        organ_msp[podcast_ID] = []
    organ_msp[podcast_ID].append(msp[i])
print("total number of podcast:", len(organ_msp.keys()))
# Out:
# total number of podcast: 1855

# %%
audio_id_in_podcast = {}
num = 0
for podcast_ID in organ_msp.keys():
    audio_id_in_podcast[podcast_ID] = {}
    for i in range(len(organ_msp[podcast_ID])):
        if organ_msp[podcast_ID][i]['need_prediction'] == 'yes':
            audio_maps = selected_audio_df[num]
            num += 1
            audio_id_in_podcast[podcast_ID][i] = audio_maps

# %%
audio_id_in_podcast['MSP-PODCAST_0001'].keys()
# Out:
# dict_keys([5, 7, 8, 11, 12, 28, 34, 39, 40, 54, 56, 58, 69, 70, 85, 88])

# %%
print("An example of sentence of no need prediction")
organ_msp['MSP-PODCAST_0001'][0]
# Out:
# An example of sentence of no need prediction
# {'id': 'MSP-PODCAST_0001_0008',
#  'need_prediction': 'no',
#  'emotion': ['Neutral', 'Neutral', 'Sad', 'Other-Inquisitive', 'Neutral'],
#  'groundtruth': ["it's it follows. that's the movie. and i know it came out january 27th in the uk. did it come out later there, or...?"],
#  'audio': 'Audio/MSP-PODCAST_0001_0008.wav',
#  'speaker': '0001',
#  'emotion_dict': {'Neutral': 0.6, 'Sad': 0.2, 'Other-Inquisitive': 0.2}}

# %%
print("An example of sentence of need prediction")
organ_msp['MSP-PODCAST_0001'][5]
# Out:
# An example of sentence of need prediction
# {'id': 'MSP-PODCAST_0001_0019',
#  'need_prediction': 'yes',
#  'emotion': ['Happy', 'Happy', 'Neutral', 'Neutral', 'Happy'],
#  'groundtruth': ["can't. i had someone in my media studies department, my degree, which was associated with the film production."],
#  'audio': 'Audio/MSP-PODCAST_0001_0019.wav',
#  'speaker': '0001',
#  'amb_emotion': ['hap', 'hap', 'neu', 'neu', 'hap'],
#  'emotion_probs': [0.4, 0.6, 0.0, 0.0],
#  'emotion_dict': {'Happy': 0.6, 'Neutral': 0.4}}

# %%
need_podcast_id = []

for ID, podcast in organ_msp.items():
    for i in range(len(podcast)):
        if podcast[i]["need_prediction"] == "yes" and ID not in need_podcast_id:
            need_podcast_id.append(ID)
len(need_podcast_id)
# Out:
# 301

# %%
print("Average number of sentences in each podcast:")
avg_sen = []
for ID in need_podcast_id:
    avg_sen.append(len(organ_msp[ID]))
print(sum(avg_sen)/len(avg_sen))
# Out:
# Average number of sentences in each podcast:
# 84.75083056478405

# %%
def Gemini_emotion_predictor(context, cur_sentence, number_of_contexts, firstflag,audio2text):
    """
    Predicts the emotional state of a speaker based on the current input sentence and the conversational context.

    Parameters:
    context (list of dict): A list of dictionaries, each representing a previous conversational turn. Each dictionary
                            should contain at least the keys 'speaker' and 'sentence' indicating who the speaker was
                            and what they said, respectively.
    cur_input (dict): A dictionary representing the current sentence to be analyzed. It should contain at least the keys
                        'speaker' and 'sentence', similar to the dictionaries in `context`.
    number_of_contexts (int, optional): The number of contextual entries to consider for emotion prediction. Defaults to 3. The more context, the more expensive.

    Returns:
    str: The predicted emotion for the current sentence, from a set of predefined emotions such as 'happy', 'sad',
            'neutral', or 'angry'.
    """
    # for simplicity, we just use whisper-tiny's transcription, feel free to use any transcription we provide, and you can combine them
    background = 'Here is the conversation of a podcast cut:\n'
    if firstflag == False:
        context_string = '\n'.join(f"{item['groundtruth'][0].encode('utf-8').decode('unicode_escape')}" for item in context[-number_of_contexts:]) + '\n'
    else:
        context_string = '\n'.join(f"{item['groundtruth'][0].encode('utf-8').decode('unicode_escape')}" for item in context) + '\n'
    new_sentence = f"'{cur_sentence['groundtruth'][0].encode('utf-8').decode('unicode_escape')}'. \n"

    if audio2text != "":
        audio = f"Please find useful information from the 88 audio features from the target sentence as references. The features are:{audio2text}"
    else:
        audio = " "

    task = f"Predict the probability of the emotion of the last sentence '{cur_sentence['groundtruth'][0].encode('utf-8').decode('unicode_escape')}' from the options [neutral, happy, angry, sad], consider the conversation context. Output statisfies the following rules.\n"
    example = "Examples: \n" + "\n".join(
    f"Sentence {i+1}: {gt['groundtruth'][0].encode('utf-8').decode('unicode_escape')} Emotion probabilities: {context[i]['emotion_dict']}"
    for i, gt in enumerate(context)
) + '\n'
    task_req1 = "Rule 1: Ignore the format of answers from examples, they contains useless emotion labels that you don't need to care. Generate a dictionary of emotion probabilities in format of {'neutral': 0.1, 'happy':0.0, 'angry':0.1, 'sad':0.8}. If you think there is only one emotion in the sentence, then give the probability to 1. \n "
    task_req2 = "Rule 2: Ensure the sum of probability equal to 1.\n"
    task_amb2 = "Rule 3: Do not explain, only the dictionary.\n \n"
    task_final = "Please check again whether your output follows the three rules. "
    prompt = background + context_string + new_sentence + audio + task + example+  task_req1 + task_req2 + task_amb2 + task_final
    # print(prompt)
    response = model.generate_content(prompt)
    return response, prompt

# %%
index_sentence = 7
number_of_context = 5
audio2text = match_features(index_sentence,audio_id_in_podcast['MSP-PODCAST_0001'])
response, prompt = Gemini_emotion_predictor(organ_msp['MSP-PODCAST_0001'][index_sentence-number_of_context:index_sentence], organ_msp['MSP-PODCAST_0001'][5], 5, False, audio2text)
response.text
# Out:
# "{'neutral': 1.0, 'happy': 0.0, 'angry': 0.0, 'sad': 0.0} \n"

# %%
prompt
# Out:
# 'Here is the conversation of a podcast cut:\ni think march 27th, cause a lot of my friends and i were going to go see that movie on friday, march 27th.\n20th. but then it had that wide release a week later.\nyeah. so david robert mitchells, it follows, he did the myth of the american sleepover?\ncan\'t. i had someone in my media studies department, my degree, which was associated with the film production.\nand someone told me it was pronounced "con." the con festival.\n\'can\'t. i had someone in my media studies department, my degree, which was associated with the film production.\'. \nPlease find useful information from the 88 audio features from the target sentence as references. The features are:{\'Average Fundamental Frequency in Semitones from 27.5 Hz\': 20.785308837890625, \'Normalized Standard Deviation of Fundamental Frequency in Semitones from 27.5 Hz\': 0.09573289752006531, \'20th Percentile of Fundamental Frequency in Semitones from 27.5 Hz\': 19.265474319458008, \'50th Percentile (Median) of Fundamental Frequency in Semitones from 27.5 Hz\': 20.252445220947266, \'80th Percentile of Fundamental Frequency in Semitones from 27.5 Hz\': 22.466402053833008, \'Range of Fundamental Frequency in Semitones from 0th to 2nd Percentile\': 3.200927734375, \'Mean Slope of Rising Fundamental Frequency in Semitones\': 100.66844940185547, \'Standard Deviation of Rising Slopes of Fundamental Frequency in Semitones\': 94.6638412475586, \'Mean Slope of Falling Fundamental Frequency in Semitones\': 20.661649703979492, \'Standard Deviation of Falling Slopes of Fundamental Frequency in Semitones\': 8.172032356262207, \'Average Loudness\': 0.20645445585250854, \'Normalized Standard Deviation of Loudness\': 0.8118767738342285, \'20th Percentile of Loudness\': 0.04873087257146835, \'50th Percentile (Median) of Loudness\': 0.1610124111175537, \'80th Percentile of Loudness\': 0.3578411936759949, \'Range of Loudness from 0th to 2nd Percentile\': 0.3091103136539459, \'Mean Slope of Rising Loudness\': 2.2480521202087402, \'Standard Deviation of Rising Slopes of Loudness\': 1.679863452911377, \'Mean Slope of Falling Loudness\': 2.098235845565796, \'Standard Deviation of Falling Slopes of Loudness\': 1.1899319887161255, \'Average Spectral Flux\': 0.058842696249485016, \'Normalized Standard Deviation of Spectral Flux\': 1.0652624368667603, \'Average Mel-Frequency Cepstral Coefficient 1\': 18.13242530822754, \'Normalized Standard Deviation of Mel-Frequency Cepstral Coefficient 1\': 1.008213996887207, \'Average Mel-Frequency Cepstral Coefficient 2\': 2.1837565898895264, \'Normalized Standard Deviation of Mel-Frequency Cepstral Coefficient 2\': 4.986769199371338, \'Average Mel-Frequency Cepstral Coefficient 3\': 7.5608415603637695, \'Normalized Standard Deviation of Mel-Frequency Cepstral Coefficient 3\': 1.5761016607284546, \'Average Mel-Frequency Cepstral Coefficient 4\': 7.990085601806641, \'Normalized Standard Deviation of Mel-Frequency Cepstral Coefficient 4\': 2.165830373764038, \'Average Jitter Local\': 0.0200937632471323, \'Normalized Standard Deviation of Jitter Local\': 0.8447858095169067, \'Average Local Shimmer in Decibels\': 1.3392695188522339, \'Normalized Standard Deviation of Local Shimmer in Decibels\': 0.8875149488449097, \'Average Harmonics-to-Noise Ratio in Decibels\': 3.6399738788604736, \'Normalized Standard Deviation of Harmonics-to-Noise Ratio in Decibels\': 0.39837709069252014, \'Average Logarithmic Ratio of Harmonics H1 to H2\': 3.943470001220703, \'Normalized Standard Deviation of Logarithmic Ratio of Harmonics H1 to H2\': 1.6719634532928467, \'Average Logarithmic Ratio of Harmonics H1 to A3\': 25.031118392944336, \'Normalized Standard Deviation of Logarithmic Ratio of Harmonics H1 to A3\': 0.2726030647754669, \'Average Frequency of the First Formant\': 514.7743530273438, \'Normalized Standard Deviation of the Frequency of the First Formant\': 0.33497098088264465, \'Average Bandwidth of the First Formant\': 1369.9381103515625 ...

# %%
# transfer response from ```json\n{'neutral': 0.0, 'happy': 0.0, 'angry': 0.0, 'sad': 1.0}\n```
def identify_format(text):
    match = re.search(r"\{.*\}", text)
    if match:
        text = match.group(0)
    result_dict = ast.literal_eval(text)
    result_dict = {k.lower(): v for k, v in result_dict.items()}

    return result_dict
def dictToList(dict, emo_labels):
    prob_list = [dict[emo] for emo in emo_labels]
    return prob_list

# %%
log = {}
def predict_sentence(index_sentence, number_of_context, data, podcast_ID):
    error = False
    emo_labels = ['neutral', 'happy', 'angry', 'sad']
    cur_sentence = data[index_sentence]
    cur_label = cur_sentence['emotion_probs']
    if index_sentence >= number_of_context:
        firstflag = False
        cur_context = data[index_sentence-number_of_context:index_sentence]
    else:
        firstflag = True
        cur_context = data[:index_sentence]

   # context is all previous sentences in the conversation
    audio2text = match_features(index_sentence, audio_id_in_podcast[podcast_ID])
        
    try:
        time.sleep(0.05)
        response,prompt = Gemini_emotion_predictor(cur_context, cur_sentence, number_of_context, firstflag, audio2text)
        response = response.text.strip()

        # input both context and the current sentence to the emotion predictor
        try:
            clear_response = identify_format(response)
            cur_pred = dictToList(clear_response, emo_labels)
            log[cur_sentence["id"]] = [prompt, response]
        except:
            # if there is an error, fill a neutral to keep the output of same dimension
            print('Gemini response is not in the right format: ', response, cur_sentence['id'])
            cur_pred = [1.0,0.0,0.0,0.0]
            error = True
            log[cur_sentence["id"]] = ["Response not in the right format", prompt, response]
    except:
        try: 
            time.sleep(5)
            response,prompt = Gemini_emotion_predictor(cur_sentence)
            response = response.text.strip()

            # input both context and the current sentence to the emotion predictor
            try:
                clear_response = identify_format(response)
                cur_pred = dictToList(clear_response, emo_labels)
                log[cur_sentence["id"]] = [prompt, response]
            except:
                # if there is an error, fill a neutral to keep the output of same dimension
                print('Gemini response is not in the right format: ', response, cur_sentence['id'])
                cur_pred = [1.0,0.0,0.0,0.0]
                error = True
                log[cur_sentence["id"]] = ["Response not in the right format", prompt, response]

        except:
            print('Gemini api has an error.: ', cur_sentence)
            cur_pred = [1.0,0.0,0.0,0.0]
            error = True
            log[cur_sentence["id"]] = ["Gemini api has an error."]

    return cur_label, cur_pred, error

# %%
log = {}
def make_predictions(data, number_of_context):
    number_errors, number_success = 0, 0
    started_sessions = []
    all_ground_truth, all_pred = [], []
    
    for podcast_ID in need_podcast_id:
        podcast = data[podcast_ID]
        if podcast_ID not in started_sessions:
            started_sessions.append(podcast_ID)
            print("Podcast ", podcast_ID)
        
        for i in range(len(podcast)):
            if podcast[i]["need_prediction"] == "yes":
                
                label, prediction, error = predict_sentence(i,number_of_context, podcast,podcast_ID)

                all_ground_truth.append(label)
                all_pred.append(prediction)
                if error == True:
                    number_errors += 1
                else: 
                    number_success += 1

        print('Number of error counts:', number_errors, "; Number of predictions:", number_success)
        number_errors, number_success = 0, 0
        print('------------------------')
        # for testing
        # if i > 50:
        #     break
    print("Total predictions: ", len(all_pred), "Total ground truth:", len(all_ground_truth))

    return all_pred, all_ground_truth

# %%
all_pred, all_ground_truth = make_predictions(organ_msp,30)
# Out:
# Podcast  MSP-PODCAST_0001
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0001_0161', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ["the second point is obviously the sex plays a big part in the movie. we haven't talked about it much beyond your intro."], 'audio': 'Audio/MSP-PODCAST_0001_0161.wav', 'speaker': '0001', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Number of error counts: 1 ; Number of predictions: 15
# ------------------------
# Total predictions:  16 Total ground truth: 16

# %%
log
# Out:
# {'MSP-PODCAST_0001_0019': ["Here is the conversation of a podcast cut:\nit's it follows. that's the movie. and i know it came out january 27th in the uk. did it come out later there, or...?\noh, i can't. i mean, i don't know the festival circuit and all that, if it did all that, but-\ni think march 27th, cause a lot of my friends and i were going to go see that movie on friday, march 27th.\n20th. but then it had that wide release a week later.\nyeah. so david robert mitchells, it follows, he did the myth of the american sleepover?\n'can't. i had someone in my media studies department, my degree, which was associated with the film production.'. \nPlease find useful information from the 88 audio features from the target sentence as references. The features are:{'Average Fundamental Frequency in Semitones from 27.5 Hz': 24.37831687927246, 'Normalized Standard Deviation of Fundamental Frequency in Semitones from 27.5 Hz': 0.1108471006155014, '20th Percentile of Fundamental Frequency in Semitones from 27.5 Hz': 21.698486328125, '50th Percentile (Median) of Fundamental Frequency in Semitones from 27.5 Hz': 24.39653778076172, '80th Percentile of Fundamental Frequency in Semitones from 27.5 Hz': 26.644458770751953, 'Range
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0003_0149
# Number of error counts: 1 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_0038
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0046
# Number of error counts: 0 ; Number of predictions: 11
# ------------------------
# Podcast  MSP-PODCAST_0047
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_0047_0248
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0047_0261
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0047_0264
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0047_0270
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_0047_0297
# Number of error counts: 5 ; Number of predictions: 49
# ------------------------
# Podcast  MSP-PODCAST_0049
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0051
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0051_0848
# Number of error counts: 1 ; Number of predictions: 17
# ------------------------
# Podcast  MSP-PODCAST_0071
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0072
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0073
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0081
# Gemini response is not in the right format:  {'neutral': 0.2, 'happy': 0.8} MSP-PODCAST_0081_0097
# Number of error counts: 1 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_0113
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0114
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0114_0217
# Number of error counts: 1 ; Number of predictions: 62
# ------------------------
# Podcast  MSP-PODCAST_0120
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0121
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0133
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0147
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0147_0203
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0147_0220
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0147_0243
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0147_0245
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0147_0482
# Number of error counts: 5 ; Number of predictions: 40
# ------------------------
# Podcast  MSP-PODCAST_0167
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0167_0130
# Number of error counts: 1 ; Number of predictions: 25
# ------------------------
# Podcast  MSP-PODCAST_0175
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0175_0271
# Number of error counts: 1 ; Number of predictions: 28
# ------------------------
# Podcast  MSP-PODCAST_0184
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Podcast  MSP-PODCAST_0187
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0189
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0190
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_0190_0083
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0190_0085
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_0190_0378
# Number of error counts: 3 ; Number of predictions: 35
# ------------------------
# Podcast  MSP-PODCAST_0193
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0194
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0201
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0202
# Gemini response is not in the right format:  {'neutral': 0.8, 'happy': 0.1, 'angry': 0.1} MSP-PODCAST_0202_0024
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0202_0035
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0202_0037
# Number of error counts: 3 ; Number of predictions: 47
# ------------------------
# Podcast  MSP-PODCAST_0211
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0214
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0217
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0218
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0218_0477', 'need_prediction': 'yes', 'emotion': ['Happy', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': [' recently, in recent years, in like the last decade or so, '], 'audio': 'Audio/MSP-PODCAST_0218_0477.wav', 'speaker': '0218', 'amb_emotion': ['hap', 'neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [0.83, 0.17, 0.0, 0.0], 'emotion_dict': {'Happy': 0.17, 'Neutral': 0.83}}
# Number of error counts: 1 ; Number of predictions: 23
# ------------------------
# Podcast  MSP-PODCAST_0219
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0220
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0221
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0221_0456', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Angry', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Neutral', 'Happy'], 'groundtruth': [' i love your podcast. i binged-watched them all the time as i wrote this. '], 'audio': 'Audio/MSP-PODCAST_0221_0456.wav', 'speaker': '0221', 'amb_emotion': ['hap', 'hap', 'hap', 'ang', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'neu', 'hap'], 'emotion_probs': [0.05, 0.9, 0.05, 0.0], 'emotion_dict': {'Happy': 0.9, 'Angry': 0.05, 'Neutral': 0.05}}
# Number of error counts: 1 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0224
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0228
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0232
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0240
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0247
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_0248
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0267
# Number of error counts: 0 ; Number of predictions: 24
# ------------------------
# Podcast  MSP-PODCAST_0272
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_0273
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0274
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0275
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0278
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0280
# Gemini response is not in the right format:  {'neutral': 0.2, 'happy': 0.8} MSP-PODCAST_0280_1758
# Number of error counts: 1 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0281
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_0281_0079
# Number of error counts: 1 ; Number of predictions: 14
# ------------------------
# Podcast  MSP-PODCAST_0282
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_0289
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0295
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0295_2135
# Number of error counts: 1 ; Number of predictions: 19
# ------------------------
# Podcast  MSP-PODCAST_0317
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0340
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0345
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0368
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Podcast  MSP-PODCAST_0370
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0370_0194', 'need_prediction': 'yes', 'emotion': ['Happy', 'Neutral', 'Happy', 'Happy', 'Neutral'], 'groundtruth': ["she's very smart and she's very articulate. she's... you know i-"], 'audio': 'Audio/MSP-PODCAST_0370_0194.wav', 'speaker': '0370', 'amb_emotion': ['hap', 'neu', 'hap', 'hap', 'neu'], 'emotion_probs': [0.4, 0.6, 0.0, 0.0], 'emotion_dict': {'Happy': 0.6, 'Neutral': 0.4}}
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0370_0397
# Number of error counts: 2 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0371
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0371_2493
# Number of error counts: 1 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0375
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0381
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0381_0459
# Number of error counts: 1 ; Number of predictions: 17
# ------------------------
# Podcast  MSP-PODCAST_0384
# Number of error counts: 0 ; Number of predictions: 17
# ------------------------
# Podcast  MSP-PODCAST_0402
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0434
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_0442
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0444
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0448
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0449
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0451
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0453
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0458
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0462
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0463
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0477
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0483
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_0498
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Podcast  MSP-PODCAST_0500
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_0535
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0537
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0538
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0538_0032
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0538_0064_0003
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0538_0065_0003
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0538_0065_0005
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0538_0065_0006
# Number of error counts: 5 ; Number of predictions: 43
# ------------------------
# Podcast  MSP-PODCAST_0550
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0559
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0560
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0561
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0566
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0569
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0570
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0571
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0572
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0573
# Gemini response is not in the right format:  {'neutral': 0.2, 'happy': 0.8} MSP-PODCAST_0573_0162
# Number of error counts: 1 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_0574
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0575
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0576
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0577
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0578
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0578_0188
# Number of error counts: 1 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0579
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0580
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0581
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0582
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0583
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0584
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0585
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0586
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0587
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0588
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0589
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0590
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0591
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0592
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0593
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0594
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0595
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0595_0377
# Number of error counts: 1 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0596
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0598
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0599
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0600
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0611
# Number of error counts: 0 ; Number of predictions: 11
# ------------------------
# Podcast  MSP-PODCAST_0615
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0619
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0619_0697
# Number of error counts: 1 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0640
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0640_0098
# Number of error counts: 1 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0648
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0656
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0656_0043
# Number of error counts: 1 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0660
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0661
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0668
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0673
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0673_0396_0003
# Number of error counts: 1 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0674
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0674_0457
# Number of error counts: 1 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0675
# Gemini response is not in the right format:  {'neutral': 0.2, 'happy': 0.8} MSP-PODCAST_0675_0167_0003
# Number of error counts: 1 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0676
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0677
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0677_0285
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0677_0287_0001
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0677_0310_0001
# Number of error counts: 3 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0678
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0678_0643_0003
# Number of error counts: 1 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0679
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0679_0266
# Number of error counts: 1 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0680
# Number of error counts: 0 ; Number of predictions: 11
# ------------------------
# Podcast  MSP-PODCAST_0681
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0682
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0683
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0684
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0685
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0686
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0687
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0688
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0689
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0690
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_0691
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0691_0602_0001
# Number of error counts: 1 ; Number of predictions: 17
# ------------------------
# Podcast  MSP-PODCAST_0692
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Podcast  MSP-PODCAST_0693
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0694
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0694_0275_0001
# Number of error counts: 1 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0695
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0695_0617_0002
# Number of error counts: 1 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0696
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0697
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0698
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0699
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0700
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0701
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0701_0440_0003
# Number of error counts: 1 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0702
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0702_0659_0003
# Number of error counts: 1 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0703
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0704
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0705
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0706
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0707
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0707_0211
# Number of error counts: 1 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0708
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0709
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0709_0068_0002
# Number of error counts: 1 ; Number of predictions: 34
# ------------------------
# Podcast  MSP-PODCAST_0710
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0710_0169
# Number of error counts: 1 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_0711
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0711_0206_0001
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0711_0305_0003
# Number of error counts: 2 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0712
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0713
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0714
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0714_0442_0002
# Number of error counts: 1 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0715
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0716
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0716_0345_0001
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0716_0345_0002
# Number of error counts: 2 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0717
# Gemini response is not in the right format:  {'neutral': 0.2, 'happy': 0.8} MSP-PODCAST_0717_0525_0001
# Number of error counts: 1 ; Number of predictions: 13
# ------------------------
# Podcast  MSP-PODCAST_0718
# Number of error counts: 0 ; Number of predictions: 17
# ------------------------
# Podcast  MSP-PODCAST_0719
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0719_0413
# Number of error counts: 1 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0721
# Number of error counts: 0 ; Number of predictions: 17
# ------------------------
# Podcast  MSP-PODCAST_0722
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0722_0133_0002
# Number of error counts: 1 ; Number of predictions: 25
# ------------------------
# Podcast  MSP-PODCAST_0723
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Podcast  MSP-PODCAST_0724
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0729
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0730
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0730_0039_0002
# Number of error counts: 1 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0731
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0736
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0736_0313_0003
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0736_0383_0002
# Number of error counts: 2 ; Number of predictions: 13
# ------------------------
# Podcast  MSP-PODCAST_0740
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0741
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0742
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0751
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0753
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0754
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0763
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0772
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Podcast  MSP-PODCAST_0773
# Number of error counts: 0 ; Number of predictions: 11
# ------------------------
# Podcast  MSP-PODCAST_0774
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0775
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0779
# Gemini response is not in the right format:  {'neutral': 0.2, 'happy': 0.8} MSP-PODCAST_0779_0594
# Number of error counts: 1 ; Number of predictions: 25
# ------------------------
# Podcast  MSP-PODCAST_0780
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0780_0115
# Number of error counts: 1 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0786
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0789
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0793
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0794
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0795
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0804
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0804_2058
# Number of error counts: 1 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0805
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_0805_2721
# Number of error counts: 1 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0806
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0807
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0808
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_0808_1773
# Number of error counts: 1 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0809
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0818
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0818_0935', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': [" oh, i laugh. every time i watch him speak, i laugh. he's got incredible comedic timing. ... "], 'audio': 'Audio/MSP-PODCAST_0818_0935.wav', 'speaker': '0818', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Number of error counts: 1 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0819
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0820
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0821
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_0821_0336
# Number of error counts: 1 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0836
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0851
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0863
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0866
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0866_0035_0002', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ["anyway, let's move on from that. well, you know, actually this is kind of relevant-"], 'audio': 'Audio/MSP-PODCAST_0866_0035_0002.wav', 'speaker': '0866', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0866_0065_0020', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Happy', 'Angry', 'Angry', 'Happy'], 'groundtruth': ['their quotes. because like i said, that all.'], 'audio': 'Audio/MSP-PODCAST_0866_0065_0020.wav', 'speaker': '0866', 'amb_emotion': ['neu', 'hap', 'ang', 'ang', 'hap'], 'emotion_probs': [0.2, 0.4, 0.4, 0.0], 'emotion_dict': {'Neutral': 0.2, 'Happy': 0.4, 'Angry': 0.4}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0866_0069_0001', 'need_prediction': 'yes', 'emotion': ['Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Sad'], 'groundtruth': ["again, that's really what this video is talking about. i mean, and they're bringing up all kinds of."], 'audio': 'Audio/MSP-PODCAST_0866_0069_0001.wav', 'speaker': '0866', 'amb_emotion': ['ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'sad'], 'emotion_probs': [0.0, 0.0, 0.92, 0.08], 'emotion_dict': {'Angry': 0.92, 'Sad': 0.08}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0866_0069_0002', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Angry', 'Angry', 'Angry'], 'groundtruth': ['like, all of our counterinsurgency manuals, all the stuff.'], 'audio': 'Audio/MSP-PODCAST_0866_0069_0002.wav', 'speaker': '0866', 'amb_emotion': ['neu', 'neu', 'ang', 'ang', 'ang'], 'emotion_probs': [0.4, 0.0, 0.6, 0.0], 'emotion_dict': {'Neutral': 0.4, 'Angry': 0.6}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0866_0072_0015', 'need_prediction': 'yes', 'emotion': ['Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry'], 'groundtruth': [" you're not going to be able to boast about how good you are at killing people "], 'audio': 'Audio/MSP-PODCAST_0866_0072_0015.wav', 'speaker': '0866', 'amb_emotion': ['ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang'], 'emotion_probs': [0.0, 0.0, 1.0, 0.0], 'emotion_dict': {'Angry': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0866_0074_0002', 'need_prediction': 'yes', 'emotion': ['Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry'], 'groundtruth': [' "we\'re not going to be able to kill as many people today", and would clap! it would be happy that they can\'t do that, '], 'audio': 'Audio/MSP-PODCAST_0866_0074_0002.wav', 'speaker': '0866', 'amb_emotion': ['ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang', 'ang'], 'emotion_probs': [0.0, 0.0, 1.0, 0.0], 'emotion_dict': {'Angry': 1.0}}
# Number of error counts: 6 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0876
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0877
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0877_0171
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0877_0619
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0877_0671_0002
# Number of error counts: 3 ; Number of predictions: 29
# ------------------------
# Podcast  MSP-PODCAST_0878
# Gemini response is not in the right format:  {'angry': 0.2, 'sad': 0.8} MSP-PODCAST_0878_0350_0002
# Number of error counts: 1 ; Number of predictions: 30
# ------------------------
# Podcast  MSP-PODCAST_0886
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0886_0040_0023
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0886_0042_0007
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0886_0044_0001
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0886_0044_0016
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0886_0044_0029
# Number of error counts: 5 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0888
# Number of error counts: 0 ; Number of predictions: 20
# ------------------------
# Podcast  MSP-PODCAST_0891
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0916
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0916_0236', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Sad', 'Happy', 'Happy'], 'groundtruth': ["we were like, why doesn't sarah sing one of the most beautiful songs and yeah. so, can we welcome mr. arthur lewis?"], 'audio': 'Audio/MSP-PODCAST_0916_0236.wav', 'speaker': '0916', 'amb_emotion': ['hap', 'hap', 'sad', 'hap', 'hap'], 'emotion_probs': [0.0, 0.8, 0.0, 0.2], 'emotion_dict': {'Happy': 0.8, 'Sad': 0.2}}
# Number of error counts: 1 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0917
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0917_0814
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0917_1528
# Number of error counts: 2 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0918
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0929
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0974
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_1102
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_1119
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1119_0209
# Number of error counts: 1 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_1213
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_1213_0052_0002
# Number of error counts: 1 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_1214
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_1214_0146
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_1214_0239_0012
# Number of error counts: 2 ; Number of predictions: 28
# ------------------------
# Podcast  MSP-PODCAST_1215
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Podcast  MSP-PODCAST_1216
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1216_0022
# Gemini response is not in the right format:  {'angry': 0.8, 'sad': 0.1, 'neutral': 0.1} MSP-PODCAST_1216_0058
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_1216_0083_0005
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_1216_0318_0003
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1216_0353
# Number of error counts: 5 ; Number of predictions: 43
# ------------------------
# Podcast  MSP-PODCAST_1217
# Number of error counts: 0 ; Number of predictions: 20
# ------------------------
# Podcast  MSP-PODCAST_1218
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1218_0107_0002
# Number of error counts: 1 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_1495
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_1533
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_1535
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_1554
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_1555
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_1556
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_1557
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_1607
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1607_0033_0001
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_1607_0052_0001
# Number of error counts: 2 ; Number of predictions: 24
# ------------------------
# Podcast  MSP-PODCAST_1608
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_1645
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1645_0001_0027
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1645_0001_0029
# Number of error counts: 2 ; Number of predictions: 19
# ------------------------
# Podcast  MSP-PODCAST_1649
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Podcast  MSP-PODCAST_1650
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_1651
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1651_0031_0001
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1651_0031_0004
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1651_0031_0005
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1651_0122
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1651_0141
# Number of error counts: 5 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_1652
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_1654
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_1655
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1655_0013
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1655_0016_0005
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1655_0149_0006
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1655_0214_0009
# Number of error counts: 4 ; Number of predictions: 19
# ------------------------
# Podcast  MSP-PODCAST_1657
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1657_0014
# Number of error counts: 1 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_1659
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_1663
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_1664
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_1665
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_1666
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_1668
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1668_0058
# Number of error counts: 1 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_1671
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1671_0051_0001
# Number of error counts: 1 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_1672
# Gemini response is not in the right format:  {'neutral': 0.83, 'happy': 0.17} MSP-PODCAST_1672_0007_0013
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1672_0007_0031
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1672_0007_0043
# Number of error counts: 3 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_1673
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1673_0018_0004
# Number of error counts: 1 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_1674
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_1675
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_1676
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_1676_0022_0014
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1676_0024_0032
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_1676_0024_0045
# Number of error counts: 3 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_1677
# Gemini api has an error.:  {'id': 'MSP-PODCAST_1677_0010_0068', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ['instead of learning consent and desire, what i instead managed to learn was guilt.'], 'audio': 'Audio/MSP-PODCAST_1677_0010_0068.wav', 'speaker': '1677', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1677_0010_0085
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1677_0010_0113
# Number of error counts: 3 ; Number of predictions: 25
# ------------------------
# Podcast  MSP-PODCAST_1678
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_1680
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_1680_0087_0004
# Number of error counts: 1 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_1681
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1681_0007_0036
# Number of error counts: 1 ; Number of predictions: 23
# ------------------------
# Podcast  MSP-PODCAST_1682
# Number of error counts: 0 ; Number of predictions: 13
# ------------------------
# Podcast  MSP-PODCAST_1683
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_1684
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1684_0042
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_1684_0068_0001
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1684_0068_0002
# Number of error counts: 3 ; Number of predictions: 21
# ------------------------
# Podcast  MSP-PODCAST_1685
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1685_0059_0003
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1685_0066_0005
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1685_0070_0005
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1685_0094_0004
# Number of error counts: 4 ; Number of predictions: 27
# ------------------------
# Podcast  MSP-PODCAST_1692
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1692_0092_0003
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1692_0112_0001
# Gemini api has an error.:  {'id': 'MSP-PODCAST_1692_0224', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Neutral'], 'groundtruth': ["well, it'll be a very, very busy show on friday. by the way, the st. louis blues. i wanted to mention the st. louis blues won in overtime last night."], 'audio': 'Audio/MSP-PODCAST_1692_0224.wav', 'speaker': '1692', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'neu'], 'emotion_probs': [0.08, 0.92, 0.0, 0.0], 'emotion_dict': {'Happy': 0.92, 'Neutral': 0.08}}
# Number of error counts: 3 ; Number of predictions: 17
# ------------------------
# Podcast  MSP-PODCAST_1693
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1693_0043_0003
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1693_0125_0007
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1693_0130
# Number of error counts: 3 ; Number of predictions: 26
# ------------------------
# Podcast  MSP-PODCAST_1694
# Number of error counts: 0 ; Number of predictions: 22
# ------------------------
# Podcast  MSP-PODCAST_1695
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Podcast  MSP-PODCAST_1697
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1697_0071_0003
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_1697_0079
# Gemini response is not in the right format:  {'happy': 0.2, 'neutral': 0.8} MSP-PODCAST_1697_0099_0005
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1697_0153
# Number of error counts: 4 ; Number of predictions: 13
# ------------------------
# Podcast  MSP-PODCAST_1699
# Gemini response is not in the right format:  {'neutral': 0.25, 'happy': 0.75} MSP-PODCAST_1699_0224
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_1699_0328_0003
# Number of error counts: 2 ; Number of predictions: 29
# ------------------------
# Podcast  MSP-PODCAST_1700
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Podcast  MSP-PODCAST_1701
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1701_0098_0012
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1701_0098_0013
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1701_0206_0002
# Number of error counts: 3 ; Number of predictions: 11
# ------------------------
# Podcast  MSP-PODCAST_1703
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1703_0061_0011
# ...
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1553
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1557
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1562
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1576
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1590
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1591
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1595
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1599
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1603
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_2343_1605
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1616
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1617
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1625
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1650
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2343_1651
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_2343_1659
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2343_1674
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1678
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1679
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1693
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1695
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1696
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1702
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1709
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1731
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1744
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1748
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1763
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1767
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2343_1774
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2343_1788
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2343_1789
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2343_1797
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2343_1798
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2343_1843
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2343_1862
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1883
# Number of error counts: 205 ; Number of predictions: 161
# ------------------------
# Podcast  MSP-PODCAST_2353
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0082
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0118
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2353_0224
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_2353_0227
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_2353_0317
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0363
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0367
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0371
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0372
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0375
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0397
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0403
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0411
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0442
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_2353_0471
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_2353_0494
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_2353_0508
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2353_0523
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0567
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0573
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0577
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_2353_0581
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0606
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0612
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0623
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0626
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0630
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0639
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0642
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0644
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0673
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0687
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0694
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_2353_0696
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_2353_0709
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_2353_0713
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_2353_0723
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_2353_0732
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0739
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0757
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0760
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0761
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0836
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0916
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2353_0917
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0931', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ['yeah. i mean, look, you keep seeing, and i hesitate to say this because-'], 'audio': 'Audio/MSP-PODCAST_2353_0931.wav', 'speaker': '2353', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0933', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ["this is july 1st. i still feel like we're not getting good data-"], 'audio': 'Audio/MSP-PODCAST_2353_0933.wav', 'speaker': '2353', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0934', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ["no, we're not.when it comes to this virus and-"], 'audio': 'Audio/MSP-PODCAST_2353_0934.wav', 'speaker': '2353', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0935', 'need_prediction': 'yes', 'emotion': ['Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Happy'], 'groundtruth': ["we're never going to because it's been politicized, but-"], 'audio': 'Audio/MSP-PODCAST_2353_0935.wav', 'speaker': '2353', 'amb_emotion': ['ang', 'ang', 'ang', 'ang', 'ang', 'hap'], 'emotion_probs': [0.0, 0.17, 0.83, 0.0], 'emotion_dict': {'Angry': 0.83, 'Happy': 0.17}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0937', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ['the death rate is 20% of-'], 'audio': 'Audio/MSP-PODCAST_2353_0937.wav', 'speaker': '2353', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0938', 'need_prediction': 'yes', 'emotion': ['Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Happy'], 'groundtruth': ["its peak. and yet we're seeing more and more cases-"], 'audio': 'Audio/MSP-PODCAST_2353_0938.wav', 'speaker': '2353', 'amb_emotion': ['ang', 'ang', 'ang', 'ang', 'ang', 'hap'], 'emotion_probs': [0.0, 0.17, 0.83, 0.0], 'emotion_dict': {'Angry': 0.83, 'Happy': 0.17}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0944', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ['... trying to stop the wind. people are going to get this.'], 'audio': 'Audio/MSP-PODCAST_2353_0944.wav', 'speaker': '2353', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0955', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ["hearing the pot's bad for you, but he's been on top-"], 'audio': 'Audio/MSP-PODCAST_2353_0955.wav', 'speaker': '2353', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0975', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ['... far shorter hospital stays as far as length goes.'], 'audio': 'Audio/MSP-PODCAST_2353_0975.wav', 'speaker': '2353', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0976', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ["so it was really interesting to read that and be like, oh yeah, i hadn't even considered-"], 'audio': 'Audio/MSP-PODCAST_2353_0976.wav', 'speaker': '2353', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0977', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ["... the fact that people haven't been going to the hospital, that are actually sick with other stuff.right?"], 'audio': 'Audio/MSP-PODCAST_2353_0977.wav', 'speaker': '2353', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0982', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ["speaking of, did you see any of biden's little press con-"], 'audio': 'Audio/MSP-PODCAST_2353_0982.wav', 'speaker': '2353', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0991', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ['so his campaign had to come in and clean that up. '], 'audio': 'Audio/MSP-PODCAST_2353_0991.wav', 'speaker': '2353', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_1000', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ['... because that was right there with my-'], 'audio': 'Audio/MSP-PODCAST_2353_1000.wav', 'speaker': '2353', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_1002', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ['... had to come back and they have a senior advisor [inaudible 00:08:08], that the testing biden has been talking is the last 15 months on the campaign trail.'], 'audio': 'Audio/MSP-PODCAST_2353_1002.wav', 'speaker': '2353', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_1005', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ["yes, trump's brain's broken, and he's saying biden's got the broken brain, but my favorite part was two-"], 'audio': 'Audio/MSP-PODCAST_2353_1005.wav', 'speaker': '2353', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_1011', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ['but then he proceeded to say, "all the secret service that heard around are t-'], 'audio': 'Audio/MSP-PODCAST_2353_1011.wav', 'speaker': '2353', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_1014', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ["... just told us you don't want to burn one test on yourself, but we're burning through tests-"], 'audio': 'Audio/MSP-PODCAST_2353_1014.wav', 'speaker': '2353', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_1015', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ['it\'s like, "hurry the [crosstalk 00:00:20]-we\'re making it rain!'], 'audio': 'Audio/MSP-PODCAST_2353_1015.wav', 'speaker': '2353', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_1020', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ['... tracy, with these events where dozens of people show up to see him.'], 'audio': 'Audio/MSP-PODCAST_2353_1020.wav', 'speaker': '2353', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Number of error counts: 65 ; Number of predictions: 149
# ------------------------
# Podcast  MSP-PODCAST_2424
# Number of error counts: 0 ; Number of predictions: 19
# ------------------------
# Podcast  MSP-PODCAST_2425
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2425_0028
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2425_0109
# Gemini response is not in the right format:  {'happy': 0.8, 'neutral': 0.2} MSP-PODCAST_2425_0232
# Number of error counts: 3 ; Number of predictions: 78
# ------------------------
# Total predictions:  4114 Total ground truth: 4114

# %%
def save_result(folder_path):

    print("Total predictions: ", len(all_pred), "Total ground truth:", len(all_ground_truth))
    # Write to a CSV file using a context manager
    with open(f'./msp_prediction/{folder_path}/pred.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(all_pred)

    with open(f'./msp_prediction/{folder_path}/truth.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(all_ground_truth)

    json.dump(log, open(f'./msp_prediction/{folder_path}/log.json', 'w'), indent=4)

# %%
save_result("fs_30con_with_audio")
# Out:
# Total predictions:  4114 Total ground truth: 4114

# %%
all_pred, all_ground_truth = make_predictions(organ_msp,5)
# Out:
# Podcast  MSP-PODCAST_0001
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0001_0161', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ["the second point is obviously the sex plays a big part in the movie. we haven't talked about it much beyond your intro."], 'audio': 'Audio/MSP-PODCAST_0001_0161.wav', 'speaker': '0001', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Number of error counts: 1 ; Number of predictions: 15
# ------------------------
# Podcast  MSP-PODCAST_0003
# Number of error counts: 0 ; Number of predictions: 11
# ------------------------
# Podcast  MSP-PODCAST_0038
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0046
# Number of error counts: 0 ; Number of predictions: 11
# ------------------------
# Podcast  MSP-PODCAST_0047
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0047_0280
# Number of error counts: 1 ; Number of predictions: 53
# ------------------------
# Podcast  MSP-PODCAST_0049
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0051
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Podcast  MSP-PODCAST_0071
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0072
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0073
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0081
# Number of error counts: 0 ; Number of predictions: 13
# ------------------------
# Podcast  MSP-PODCAST_0113
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0114
# Number of error counts: 0 ; Number of predictions: 63
# ------------------------
# Podcast  MSP-PODCAST_0120
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0121
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0133
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0147
# Number of error counts: 0 ; Number of predictions: 45
# ------------------------
# Podcast  MSP-PODCAST_0167
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Podcast  MSP-PODCAST_0175
# Number of error counts: 0 ; Number of predictions: 29
# ------------------------
# Podcast  MSP-PODCAST_0184
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Podcast  MSP-PODCAST_0187
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0189
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0190
# Number of error counts: 0 ; Number of predictions: 38
# ------------------------
# Podcast  MSP-PODCAST_0193
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0194
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0201
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0202
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Podcast  MSP-PODCAST_0211
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0214
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0217
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0218
# Number of error counts: 0 ; Number of predictions: 24
# ------------------------
# Podcast  MSP-PODCAST_0219
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0220
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0221
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0221_0456', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Angry', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Neutral', 'Happy'], 'groundtruth': [' i love your podcast. i binged-watched them all the time as i wrote this. '], 'audio': 'Audio/MSP-PODCAST_0221_0456.wav', 'speaker': '0221', 'amb_emotion': ['hap', 'hap', 'hap', 'ang', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'hap', 'neu', 'hap'], 'emotion_probs': [0.05, 0.9, 0.05, 0.0], 'emotion_dict': {'Happy': 0.9, 'Angry': 0.05, 'Neutral': 0.05}}
# Number of error counts: 1 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0224
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0228
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0232
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0240
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0247
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_0248
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0267
# Number of error counts: 0 ; Number of predictions: 24
# ------------------------
# Podcast  MSP-PODCAST_0272
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_0273
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0274
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0275
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0278
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0280
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0281
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Podcast  MSP-PODCAST_0282
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_0289
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0295
# Number of error counts: 0 ; Number of predictions: 20
# ------------------------
# Podcast  MSP-PODCAST_0317
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0340
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0345
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0368
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Podcast  MSP-PODCAST_0370
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0371
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_0375
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0381
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Podcast  MSP-PODCAST_0384
# Number of error counts: 0 ; Number of predictions: 17
# ------------------------
# Podcast  MSP-PODCAST_0402
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0434
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_0442
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0444
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0448
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0448_0148
# Number of error counts: 1 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0449
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0451
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0453
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0458
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0462
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0463
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0477
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0483
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_0498
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Podcast  MSP-PODCAST_0500
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_0535
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0537
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0538
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0538_0070
# Number of error counts: 1 ; Number of predictions: 47
# ------------------------
# Podcast  MSP-PODCAST_0550
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0559
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0560
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0561
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0566
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0569
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0570
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0571
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0572
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0573
# Number of error counts: 0 ; Number of predictions: 11
# ------------------------
# Podcast  MSP-PODCAST_0574
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0575
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0576
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0577
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0578
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0579
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0580
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0581
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0582
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0583
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0584
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0585
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0586
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0587
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0588
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0589
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0590
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0591
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0592
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0593
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0594
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0595
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0596
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0598
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0599
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0600
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0611
# Number of error counts: 0 ; Number of predictions: 11
# ------------------------
# Podcast  MSP-PODCAST_0615
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0619
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0640
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0648
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0656
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0660
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0661
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0668
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0673
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_0674
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0675
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0676
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0677
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0678
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_0678_0140_0003
# Number of error counts: 1 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0679
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_0680
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0680_0261_0001
# Number of error counts: 1 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_0681
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0682
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0683
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0684
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0685
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0686
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0687
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0688
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0689
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0690
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_0691
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Podcast  MSP-PODCAST_0692
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Podcast  MSP-PODCAST_0693
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0694
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0695
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0696
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0697
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0698
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0699
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0700
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0701
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0702
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0703
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0704
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0705
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0706
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0707
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0708
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0709
# Number of error counts: 0 ; Number of predictions: 35
# ------------------------
# Podcast  MSP-PODCAST_0710
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0710_0169
# Number of error counts: 1 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_0711
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_0712
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0713
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0714
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_0715
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0716
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0717
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Podcast  MSP-PODCAST_0718
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0718_0111_0003
# Number of error counts: 1 ; Number of predictions: 16
# ------------------------
# Podcast  MSP-PODCAST_0719
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_0721
# Number of error counts: 0 ; Number of predictions: 17
# ------------------------
# Podcast  MSP-PODCAST_0722
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_0722_0081_0002
# Number of error counts: 1 ; Number of predictions: 25
# ------------------------
# Podcast  MSP-PODCAST_0723
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Podcast  MSP-PODCAST_0724
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0729
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_0729_0154_0001
# Number of error counts: 1 ; Number of predictions: 0
# ------------------------
# Podcast  MSP-PODCAST_0730
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0731
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0736
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Podcast  MSP-PODCAST_0740
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0741
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0742
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_0751
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0753
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0754
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0763
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0772
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Podcast  MSP-PODCAST_0773
# Number of error counts: 0 ; Number of predictions: 11
# ------------------------
# Podcast  MSP-PODCAST_0774
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0775
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0779
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Podcast  MSP-PODCAST_0780
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0786
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0789
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0793
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0794
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0795
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0804
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0805
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_0806
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0807
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0808
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0809
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0818
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0819
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_0820
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0821
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0836
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0851
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0863
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_0866
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0866_0035_0002', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ["anyway, let's move on from that. well, you know, actually this is kind of relevant-"], 'audio': 'Audio/MSP-PODCAST_0866_0035_0002.wav', 'speaker': '0866', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Number of error counts: 1 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_0876
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0877
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0877_0171
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_0877_0343
# Number of error counts: 2 ; Number of predictions: 30
# ------------------------
# Podcast  MSP-PODCAST_0878
# Number of error counts: 0 ; Number of predictions: 31
# ------------------------
# Podcast  MSP-PODCAST_0886
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_0886_0042_0007
# Number of error counts: 1 ; Number of predictions: 12
# ------------------------
# Podcast  MSP-PODCAST_0888
# Number of error counts: 0 ; Number of predictions: 20
# ------------------------
# Podcast  MSP-PODCAST_0891
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0916
# Gemini api has an error.:  {'id': 'MSP-PODCAST_0916_0236', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Sad', 'Happy', 'Happy'], 'groundtruth': ["we were like, why doesn't sarah sing one of the most beautiful songs and yeah. so, can we welcome mr. arthur lewis?"], 'audio': 'Audio/MSP-PODCAST_0916_0236.wav', 'speaker': '0916', 'amb_emotion': ['hap', 'hap', 'sad', 'hap', 'hap'], 'emotion_probs': [0.0, 0.8, 0.0, 0.2], 'emotion_dict': {'Happy': 0.8, 'Sad': 0.2}}
# Number of error counts: 1 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_0917
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_0918
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_0929
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_0974
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_1102
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_1119
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_1213
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_1214
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Podcast  MSP-PODCAST_1215
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Podcast  MSP-PODCAST_1216
# Number of error counts: 0 ; Number of predictions: 48
# ------------------------
# Podcast  MSP-PODCAST_1217
# Number of error counts: 0 ; Number of predictions: 20
# ------------------------
# Podcast  MSP-PODCAST_1218
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_1495
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_1533
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_1535
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_1554
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_1555
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_1556
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1556_0051_0005
# Number of error counts: 1 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_1557
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_1607
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_1607_0056
# Number of error counts: 1 ; Number of predictions: 25
# ------------------------
# Podcast  MSP-PODCAST_1608
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_1645
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Podcast  MSP-PODCAST_1649
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Podcast  MSP-PODCAST_1650
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_1651
# Number of error counts: 0 ; Number of predictions: 17
# ------------------------
# Podcast  MSP-PODCAST_1652
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_1654
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_1655
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1655_0009_0008
# Number of error counts: 1 ; Number of predictions: 22
# ------------------------
# Podcast  MSP-PODCAST_1657
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_1659
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_1663
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_1664
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_1665
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_1666
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_1668
# Number of error counts: 0 ; Number of predictions: 11
# ------------------------
# Podcast  MSP-PODCAST_1671
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Podcast  MSP-PODCAST_1672
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1672_0007_0043
# Number of error counts: 1 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_1673
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_1674
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Podcast  MSP-PODCAST_1675
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1675_0104_0003
# Number of error counts: 1 ; Number of predictions: 7
# ------------------------
# Podcast  MSP-PODCAST_1676
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_1676_0024_0037
# Number of error counts: 1 ; Number of predictions: 14
# ------------------------
# Podcast  MSP-PODCAST_1677
# Gemini api has an error.:  {'id': 'MSP-PODCAST_1677_0010_0031', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ['... "everyone knows about that," and i realized i hadn\'t invented simulated sex.'], 'audio': 'Audio/MSP-PODCAST_1677_0010_0031.wav', 'speaker': '1677', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Number of error counts: 1 ; Number of predictions: 27
# ------------------------
# Podcast  MSP-PODCAST_1678
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_1680
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_1681
# Number of error counts: 0 ; Number of predictions: 24
# ------------------------
# Podcast  MSP-PODCAST_1682
# Number of error counts: 0 ; Number of predictions: 13
# ------------------------
# Podcast  MSP-PODCAST_1683
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_1683_0024_0012
# Number of error counts: 1 ; Number of predictions: 11
# ------------------------
# Podcast  MSP-PODCAST_1684
# Number of error counts: 0 ; Number of predictions: 24
# ------------------------
# Podcast  MSP-PODCAST_1685
# Number of error counts: 0 ; Number of predictions: 31
# ------------------------
# Podcast  MSP-PODCAST_1692
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1692_0112_0001
# Number of error counts: 1 ; Number of predictions: 19
# ------------------------
# Podcast  MSP-PODCAST_1693
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1693_0263_0007
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1693_0263_0008
# Number of error counts: 2 ; Number of predictions: 27
# ------------------------
# Podcast  MSP-PODCAST_1694
# Number of error counts: 0 ; Number of predictions: 22
# ------------------------
# Podcast  MSP-PODCAST_1695
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1695_0220
# Number of error counts: 1 ; Number of predictions: 15
# ------------------------
# Podcast  MSP-PODCAST_1697
# Number of error counts: 0 ; Number of predictions: 17
# ------------------------
# Podcast  MSP-PODCAST_1699
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_1699_0328_0003
# Number of error counts: 1 ; Number of predictions: 30
# ------------------------
# Podcast  MSP-PODCAST_1700
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Podcast  MSP-PODCAST_1701
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Podcast  MSP-PODCAST_1703
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Podcast  MSP-PODCAST_1704
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_1705
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Podcast  MSP-PODCAST_1709
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Podcast  MSP-PODCAST_1908
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1908_0848
# Number of error counts: 1 ; Number of predictions: 71
# ------------------------
# Podcast  MSP-PODCAST_1909
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1909_0781
# Number of error counts: 1 ; Number of predictions: 148
# ------------------------
# Podcast  MSP-PODCAST_1910
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_1910_0081
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1910_0095
# Gemini response is not in the right format:  {'neutral': 1.0} MSP-PODCAST_1910_0138
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_1910_0153
# Number of error counts: 4 ; Number of predictions: 43
# ------------------------
# Podcast  MSP-PODCAST_1917
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Podcast  MSP-PODCAST_2053
# Number of error counts: 0 ; Number of predictions: 44
# ------------------------
# Podcast  MSP-PODCAST_2054
# Number of error counts: 0 ; Number of predictions: 35
# ------------------------
# Podcast  MSP-PODCAST_2055
# Number of error counts: 0 ; Number of predictions: 32
# ------------------------
# Podcast  MSP-PODCAST_2056
# Number of error counts: 0 ; Number of predictions: 19
# ------------------------
# Podcast  MSP-PODCAST_2057
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Podcast  MSP-PODCAST_2058
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Podcast  MSP-PODCAST_2104
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Podcast  MSP-PODCAST_2195
# Number of error counts: 0 ; Number of predictions: 11
# ------------------------
# Podcast  MSP-PODCAST_2197
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Podcast  MSP-PODCAST_2198
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Podcast  MSP-PODCAST_2199
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2199_0461
# Number of error counts: 1 ; Number of predictions: 14
# ------------------------
# Podcast  MSP-PODCAST_2203
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Podcast  MSP-PODCAST_2329
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_0084
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_0094
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_0106
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_0109
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_0176
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_0209
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_0252
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_0347
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_0427
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_0462
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_0534
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_0536
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_2329_0884
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_0999
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_1008
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_1340
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_1343
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_2329_1409
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_1555
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2329_1661
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2329_1702', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ["[inaudible 00:06:19].well.ain't nothing wrong with that.what's wrong with that?"], 'audio': 'Audio/MSP-PODCAST_2329_1702.wav', 'speaker': '2329', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Number of error counts: 21 ; Number of predictions: 253
# ------------------------
# Podcast  MSP-PODCAST_2336
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2336_0293
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2336_0806
# Number of error counts: 2 ; Number of predictions: 33
# ------------------------
# Podcast  MSP-PODCAST_2337
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2337_0246
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2337_0452', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': [" mm-hmm (affirmative).and now maybe we'll see it with climate change "], 'audio': 'Audio/MSP-PODCAST_2337_0452.wav', 'speaker': '2337', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2337_0453', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': [' instead of your argument being, come on.'], 'audio': 'Audio/MSP-PODCAST_2337_0453.wav', 'speaker': '2337', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2337_0456', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': [' another example, for me anyway, '], 'audio': 'Audio/MSP-PODCAST_2337_0456.wav', 'speaker': '2337', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2337_0463', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': [" it's okay, we're in charge. "], 'audio': 'Audio/MSP-PODCAST_2337_0463.wav', 'speaker': '2337', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2337_0473
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2337_0505
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2337_0684', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': [], 'audio': 'Audio/MSP-PODCAST_2337_0684.wav', 'speaker': '2337', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2337_0691', 'need_prediction': 'yes', 'emotion': ['Happy', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ['a child?they want the president to unblock them.'], 'audio': 'Audio/MSP-PODCAST_2337_0691.wav', 'speaker': '2337', 'amb_emotion': ['hap', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [0.8, 0.2, 0.0, 0.0], 'emotion_dict': {'Happy': 0.2, 'Neutral': 0.8}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2337_0705', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': [' a huge can of worms can now... and '], 'audio': 'Audio/MSP-PODCAST_2337_0705.wav', 'speaker': '2337', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2337_0707', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': [" the president, what if you're the "], 'audio': 'Audio/MSP-PODCAST_2337_0707.wav', 'speaker': '2337', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2337_0711', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': [' be forced to not block anyone on twitter?'], 'audio': 'Audio/MSP-PODCAST_2337_0711.wav', 'speaker': '2337', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2337_0748
# Number of error counts: 13 ; Number of predictions: 101
# ------------------------
# Podcast  MSP-PODCAST_2343
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0042', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ['this is the greatest memes ever.'], 'audio': 'Audio/MSP-PODCAST_2343_0042.wav', 'speaker': '2343', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0043', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ['i can explain that.'], 'audio': 'Audio/MSP-PODCAST_2343_0043.wav', 'speaker': '2343', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0045', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ["two beans, can't explain that.walk-in supermarket, doors open, by itself. can't explain that."], 'audio': 'Audio/MSP-PODCAST_2343_0045.wav', 'speaker': '2343', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_2343_0088
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0147', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': [], 'audio': 'Audio/MSP-PODCAST_2343_0147.wav', 'speaker': '2343', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0159', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ['a ton of money. but muhammad ali and jordan-'], 'audio': 'Audio/MSP-PODCAST_2343_0159.wav', 'speaker': '2343', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0168', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ['disheartening to watch two women fight who could just beat the living out of me.'], 'audio': 'Audio/MSP-PODCAST_2343_0168.wav', 'speaker': '2343', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0171', 'need_prediction': 'yes', 'emotion': ['Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Neutral'], 'groundtruth': ['i would get my ass handed to me.probably.right.'], 'audio': 'Audio/MSP-PODCAST_2343_0171.wav', 'speaker': '2343', 'amb_emotion': ['sad', 'sad', 'sad', 'sad', 'sad', 'neu'], 'emotion_probs': [0.17, 0.0, 0.0, 0.83], 'emotion_dict': {'Sad': 0.83, 'Neutral': 0.17}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0175', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ['even get clothes on.[crosstalk 00:07:39].they must all [crosstalk 00:07:40]-'], 'audio': 'Audio/MSP-PODCAST_2343_0175.wav', 'speaker': '2343', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0184', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ["... get it on if you can't get it off."], 'audio': 'Audio/MSP-PODCAST_2343_0184.wav', 'speaker': '2343', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0191', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': [], 'audio': 'Audio/MSP-PODCAST_2343_0191.wav', 'speaker': '2343', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0198', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ["my head. so tell me what you just said and what it means.i'm not going to. per-"], 'audio': 'Audio/MSP-PODCAST_2343_0198.wav', 'speaker': '2343', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0200', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ['i want to know, brian.it was an inside joke.'], 'audio': 'Audio/MSP-PODCAST_2343_0200.wav', 'speaker': '2343', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0201', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ['between you and?'], 'audio': 'Audio/MSP-PODCAST_2343_0201.wav', 'speaker': '2343', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0204', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ["it's probably a bad time to do an inside joke.yeah."], 'audio': 'Audio/MSP-PODCAST_2343_0204.wav', 'speaker': '2343', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini response is not in the right format:  {'happy': 1.0} MSP-PODCAST_2343_0231
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0249', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': [], 'audio': 'Audio/MSP-PODCAST_2343_0249.wav', 'speaker': '2343', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0251', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ["where are you going with this?well, i want to... because they're talking about the actual tennis match and i know nothing about tennis other than the-"], 'audio': 'Audio/MSP-PODCAST_2343_0251.wav', 'speaker': '2343', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0252', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ["there's venus and serena williams."], 'audio': 'Audio/MSP-PODCAST_2343_0252.wav', 'speaker': '2343', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0266', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ["date opponents, one being angelique, but it makes this victory even sweeter to know how hard i've had to work for it."], 'audio': 'Audio/MSP-PODCAST_2343_0266.wav', 'speaker': '2343', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0267', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ["interesting, interesting. so she's all about working hard."], 'audio': 'Audio/MSP-PODCAST_2343_0267.wav', 'speaker': '2343', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2343_0289', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ["they're not likely.well, i don't think you necessarily have to say that, though, either because that-"], 'audio': 'Audio/MSP-PODCAST_2343_0289.wav', 'speaker': '2343', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_0295
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_0471
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_0484
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_0593
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_0688
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_0790
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_0796
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_0912
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_0914
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_0953
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_0982
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_0987
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1041
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2343_1126
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1180
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1226
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1420
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1495
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1591
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1595
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1603
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1616
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2343_1700
# Gemini response is not in the right format:  {'sad': 1.0} MSP-PODCAST_2343_1755
# Number of error counts: 46 ; Number of predictions: 320
# ------------------------
# Podcast  MSP-PODCAST_2353
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0110
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0147
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0196
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0220
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0371
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0757
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0847
# Gemini response is not in the right format:  {'angry': 1.0} MSP-PODCAST_2353_0916
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0931', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ['yeah. i mean, look, you keep seeing, and i hesitate to say this because-'], 'audio': 'Audio/MSP-PODCAST_2353_0931.wav', 'speaker': '2353', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0933', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ["this is july 1st. i still feel like we're not getting good data-"], 'audio': 'Audio/MSP-PODCAST_2353_0933.wav', 'speaker': '2353', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0934', 'need_prediction': 'yes', 'emotion': ['Happy', 'Happy', 'Happy', 'Happy', 'Happy'], 'groundtruth': ["no, we're not.when it comes to this virus and-"], 'audio': 'Audio/MSP-PODCAST_2353_0934.wav', 'speaker': '2353', 'amb_emotion': ['hap', 'hap', 'hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0], 'emotion_dict': {'Happy': 1.0}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0935', 'need_prediction': 'yes', 'emotion': ['Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Happy'], 'groundtruth': ["we're never going to because it's been politicized, but-"], 'audio': 'Audio/MSP-PODCAST_2353_0935.wav', 'speaker': '2353', 'amb_emotion': ['ang', 'ang', 'ang', 'ang', 'ang', 'hap'], 'emotion_probs': [0.0, 0.17, 0.83, 0.0], 'emotion_dict': {'Angry': 0.83, 'Happy': 0.17}}
# Gemini api has an error.:  {'id': 'MSP-PODCAST_2353_0937', 'need_prediction': 'yes', 'emotion': ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral'], 'groundtruth': ['the death rate is 20% of-'], 'audio': 'Audio/MSP-PODCAST_2353_0937.wav', 'speaker': '2353', 'amb_emotion': ['neu', 'neu', 'neu', 'neu', 'neu'], 'emotion_probs': [1.0, 0.0, 0.0, 0.0], 'emotion_dict': {'Neutral': 1.0}}
# Number of error counts: 13 ; Number of predictions: 201
# ------------------------
# Podcast  MSP-PODCAST_2424
# Number of error counts: 0 ; Number of predictions: 19
# ------------------------
# Podcast  MSP-PODCAST_2425
# Number of error counts: 0 ; Number of predictions: 81
# ------------------------
# Total predictions:  4114 Total ground truth: 4114

# %%
save_result("fs_5con")
# Out:
# Total predictions:  4114 Total ground truth: 4114

# %%
import eval_metrics as em
from sklearn.metrics import recall_score, balanced_accuracy_score
from sklearn.metrics import f1_score, accuracy_score

# %%
KL_values = []
for i in range(len(all_pred)):
    KL_values.append(em.KL(all_ground_truth[i],all_pred[i]))
round(np.mean(KL_values),2)
# Out:
# /Users/macbookpro/Documents/Research Project/LLM_Ambiguous_Emotion/eval_metrics.py:12: RuntimeWarning: divide by zero encountered in log
#   KL_value = np.sum(np.where(a != 0, a * np.log(a / b), 0))
# /Users/macbookpro/Documents/Research Project/LLM_Ambiguous_Emotion/eval_metrics.py:12: RuntimeWarning: invalid value encountered in multiply
#   KL_value = np.sum(np.where(a != 0, a * np.log(a / b), 0))
# 10.76

# %%
BC_values = []
for i in range(len(all_pred)):
    BC_dic, BC_co = em.BC(all_ground_truth[i],all_pred[i])
    BC_values.append(BC_co)
np.mean(BC_values)
# Out:
# 0.5514178658240155

# %%
R_square = []
for i in range(len(all_pred)):
    R_square.append(em.R(all_ground_truth[i],all_pred[i]))
np.mean(R_square)
# Out:
# 0.5349854399611085

# %%
em.ECE(all_pred, all_ground_truth)
# Out:
# array([0.46781721])

# %%
truth_labels = []
pred_labels = []
for i in range(len(all_pred)):
    truth_labels.append(np.argmax(all_ground_truth[i]))
    pred_labels.append(np.argmax(all_pred[i]))

# %%
print("Accuracy: ", accuracy_score(truth_labels, pred_labels))
print("UAR ", balanced_accuracy_score(truth_labels, pred_labels))
print("Weighted-F1 score: ", f1_score(truth_labels, pred_labels, average='weighted'))
# Out:
# Accuracy:  0.512396694214876
# UAR  0.44077592755299366
# Weighted-F1 score:  0.5317478685444739

# %%
log['MSP-PODCAST_2353_0879'][2]
# Out:
# "{'angry': 1.0}"

# %%
response = model.generate_content("Could you transfer the dictionary {'angry': 1.0} into a distribution of emotions with probabilities for each emotion. [neutral, happy, angry, sad]")
response.text
# Out:
# 'Here\'s how we can approach this, along with the reasoning:\n\n**Understanding the Challenge**\n\nYou have a dictionary representing a single emotion ("angry") with a certainty level (1.0).  We need to create a probability distribution for four emotions (neutral, happy, angry, sad).\n\n**Assumptions and Considerations**\n\n* **Lack of Information:** We have no information about the likelihood of the other emotions.  \n* **Default Distribution:**  We need to make assumptions to fill in the missing probabilities.  \n* **Equal Distribution (Simple Approach):** A simple way is to assume that the remaining emotions are equally likely.\n\n**Solution**\n\n1. **Start with the given emotion:**  "angry" has a probability of 1.0.\n\n2. **Allocate the remaining probability:** The remaining probability is 1.0 - 1.0 = 0.0.  We need to distribute this equally among the other three emotions.\n\n3. **Calculate probability for each remaining emotion:** 0.0 / 3 = 0.0.\n\n**Resulting Distribution**\n\n* **neutral:** 0.0\n* **happy:** 0.0\n* **angry:** 1.0\n* **sad:** 0.0\n\n**Important Notes**\n\n* **Uncertainty:** This distribution is highly uncertain.  Without more context, it\'s impossible to be confident about the likelihood of the other emotions.\n* **Alternative Approaches:**  Depending on your application, you might use more complex methods like:\n    * **Contextual Inference:** Consider the situation or context where this emotion is being observed.\n    * **Prior Probabilities:**  If you have general knowledge about the prevalence of these emotions, you could use those as a starting point.\n\nLet me know if you have more information about the context or if you\'d like to explore more sophisticated distribution methods! \n'

# %%
prob_IDs = []
for i, podcast_ID in enumerate(log):
    item = log[podcast_ID]
    if len(item) == 3:
        if item[0] == 'Response not in the right format':
            
            prob_IDs.append(i)
len(prob_IDs)
# Out:
# 490

# %%
log['MSP-PODCAST_2353_0879']
# Out:
# ['Response not in the right format',
#  "Here is the conversation of a podcast cut:\n... called the patio, but when you got a pad like that-\nstrolling down main street in st. louis and these people just came out onto their lawn and started pointing guns at these innocent protest-\nreason 97,342 why the mainstream media needs to be destroyed.\na 100% but how many people saw that and cheered for those guy?-\nyeah. so there are people-\nand to use them. and so i'm really worried that this is going to escalate to where we are really going to start seeing-\nthink if trump wins again, he can nego-\n... it should. we're to the point, like we've been talking about-\noh, in michigan, you've got detroit.\nright?because in countries come and go, all these lines change like there's consequence-\n'... to goes but mexico. we've kind of moved lines a little bit, that-'. \nPredict the probability of the emotion of the last sentence '... to goes but mexico. we've kind of moved lines a little bit, that-' from the options [neutral, happy, angry, sad], consider the conversation context. Output statisfies the following rules.\nExamples: \nSentence 1: ... called the patio, but when you got a pad like that- Emotion probabilities: {'Neutral': 1.0}\nSentence 2: strolling down main street in st. louis and these people just came out onto their lawn and started pointing guns at these innocent protest- Emotion probabilities: {'Angry': 1.0}\nSentence 3: reason 97,342 why the mainstream media needs to be destroyed. Emotion probabilities: {'Disgust': 0.83, 'Neutral': 0.17}\nSentence 4: a 100% but how many people saw that and cheered for those guy?- Emotion probabilities: {'Happy': 1.0}\nSentence 5: yeah. so there are people- Emotion probabilities: {'Angry': 0.83, 'Surprise': 0.17}\nSentence 6: and to use them. and so i'm really worried that this is going to escalate to where we are really going to start seeing- Emotion probabilities: {'Happy': 1.0}\nSentence 7: think if trump wins again, he can nego- Emotion probabilities: {'Happy': 1.0}\nSentence 8: ... it should. we're to the point, like we've been talking about- Emotion probabilities: {'Happy': 1.0}\nSentence 9: oh, in michigan, you've got detroit. Emotion probabilities: {'Fear': 1.0}\nSentence 10: right?because in countries come and go, all these lines change like there's consequence- Emotion probabilities: {'Neutral': 1.0}\nRule 1: Ignore the format of answers from examples, they contains useless emotion labels that you don't need to care. Generate a dictionary of emotion probabilities in format of {'neutral': 0.1, 'happy':0.0, 'angry':0.1, 'sad':0.8}. If you think there is only one emotion in the sentence, then give the probability to 1. \n Rule 2: Ensure the sum of probability equal to 1.\nRule 3: Do not explain, only the dictionary.\n \nPlease check again whether your output follows the three rules. ",
#  "{'angry': 1.0}"]
