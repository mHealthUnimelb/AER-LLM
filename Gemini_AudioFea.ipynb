# %% [markdown]
# Step 1. Install and import packages

# %%
import textwrap
import csv
import json
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import time
import google.generativeai as genai
import re 

from IPython.display import display
from IPython.display import Markdown
import ast 
import pandas as pd
from collections import Counter
import numpy as np
from scipy.spatial import distance
import os
from pathlib import Path

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY= 'AIzaSyCJB2LdrcpnNaRRQeRWDv7fxIUQONxOgiQ'

genai.configure(api_key=GOOGLE_API_KEY)

model = genai.GenerativeModel('gemini-1.5-flash')

# %% [markdown]
# Step 2. Get the dialog order for all sessions

# %%
def get_dialog_order(tran_path):
    diaglog_ids = []
    for session in range(1,6):
        session = "Session" + str(session)
        session_path = os.path.join(tran_path, session)
        trans_path = os.path.join(session_path, 'dialog/transcriptions')
        trans_lists = sorted(os.listdir(trans_path))
        for i in range(len(trans_lists)):
            full_trans_path = os.path.join(trans_path, trans_lists[i])
            texts = open(full_trans_path, 'r').readlines()
            for text in texts:
                sentence_id = text.split()[0]
                diaglog_ids.append(sentence_id)
    return diaglog_ids
tran_path = './data/IEMOCAP_full_release/'
diaglog_id_orders = get_dialog_order(tran_path)
print("Number of sentence ids across all sessions: ", len(diaglog_id_orders))
# Out:
# Number of sentence ids across all sessions:  10238

# %% [markdown]
# Step 3. Load text data

# %%
file_path = './data/iemocap_ambiguous.json'
data = json.load(open(file_path))
for i in range(len(data)):
    data[i]['speaker'] = data[i]['id'][:5] + data[i]['id'].split("_")[2][0]

# %% [markdown]
# Load audio data

# %%
import pickle
with open('./data/iemocap_egemaps.pkl', 'rb') as f:
    audio_features = pickle.load(f, encoding='latin1')

# %% [markdown]
# Transfer three ground true labels to distributions

# %%
def get_label_prob(data):

    emo_labels = ['neu', 'hap', 'ang', 'sad']
    emotion_code_dict = {"Neutral state":"neu", "Happiness":"hap", "Anger":"ang", "Sadness":"sad", "Frustration":"others", "Contempt":"others", "Excitement":"others", "Surprise":"others", "Disgust":"others", "Fear":"others", "Other": "others"}
    num_out_labels = 0
    for item in data:
        amb_labels = []
        if item['need_prediction'] == 'yes':
            for emo in item['emotion']:
                amb_labels.append(emotion_code_dict[emo])

            filtered_labels = [label for label in amb_labels if label in emo_labels]
            for label in amb_labels:
                if label not in emo_labels:
                    num_out_labels += 1


            item['amb_emotion'] = filtered_labels

            emotion_counts = Counter(filtered_labels)
            total_count = sum(emotion_counts.values())
            
            probs = {emo: round(emotion_counts[emo]/total_count,2) for emo in emo_labels}
            item['emotion_probs'] = [probs[emo] for emo in emo_labels]

    return data, num_out_labels

new_data, num_out_labels = get_label_prob(data)
print("Number of instances that their emotions are outside four labels: ", num_out_labels)
# Out:
# Number of instances that their emotions are outside four labels:  0

# %% [markdown]
# Rearrange data into sessions:

# %%
# rearrange the data into sessions
def rearrange_data(data):
    session_dict = {}
    for item in data:
        session_impro_id = item['id'][:6]
        if session_impro_id not in session_dict:
            session_dict[session_impro_id] = []
        session_dict[session_impro_id].append(item)
    return session_dict

session_data = rearrange_data(new_data)
print('session in the data')
print(list(session_data.keys()))
print("number of session_improvisations:",len(session_data))
print('--------\na sample entry:')
for key, value in session_data[list(session_data.keys())[0]][0].items():
    print(f"{key}: {value}")
# Out:
# session in the data
# ['Ses01F', 'Ses01M', 'Ses02F', 'Ses02M', 'Ses03F', 'Ses03M', 'Ses04F', 'Ses04M', 'Ses05F', 'Ses05M']
# number of session_improvisations: 10
# --------
# a sample entry:
# id: Ses01F_impro01_F000
# emotion: ['Neutral state', 'Neutral state', 'Neutral state']
# need_prediction: yes
# speaker: Ses01F
# groundtruth: Excuse me.
# audio: IEMOCAP_full_release/Session/1/sentences/wav/Ses01F_impro01_F000/Ses01F_impro01_F000.wav
# amb_emotion: ['neu', 'neu', 'neu']
# emotion_probs: [1.0, 0.0, 0.0, 0.0]

# %% [markdown]
# Reorder data according to dialog ids

# %%
def order_sentences(diaglog_id_orders, new_data):
    order_sen = []
    for sentence_id in diaglog_id_orders:
        for item in new_data:
            if item['id'] == sentence_id:
                order_sen.append(item)
                break
    return order_sen
order_data = order_sentences(diaglog_id_orders, new_data)
print("Number of ordered sentences across all sessions: ", len(order_data))
print("List of first 5 sentence ids in the first sessions: \n", [item['id'] for item in order_data[0:5]])
num_pred_text = 0
for i in range(len(order_data)):
    if order_data[i]['need_prediction'] == 'yes':
        num_pred_text += 1
print("Number of sentences that need prediction: ", num_pred_text)
# Out:
# Number of ordered sentences across all sessions:  10039
# List of first 5 sentence ids in the first sessions:
#  ['Ses01F_impro01_F000', 'Ses01F_impro01_M000', 'Ses01F_impro01_F001', 'Ses01F_impro01_M001', 'Ses01F_impro01_F002']
# Number of sentences that need prediction:  4370

# %%
order_audio_data = order_sentences(diaglog_id_orders, audio_features)
print("Number of ordered sentences across all sessions: ", len(order_audio_data))
for i in range(len(order_audio_data)):
    assert order_audio_data[i]['id'] == order_data[i]['id']
num_pred_audio = 0
num_pred_both = 0 
for i in range(len(order_audio_data)):
    if order_audio_data[i]['need_prediction'] == 'yes':
        num_pred_audio += 1
    if order_audio_data[i]['need_prediction'] == 'yes' and order_data[i]['need_prediction'] == 'yes':
        num_pred_both += 1
print("Number of sentences that need prediction: ", num_pred_audio)
print("Number of sentences that need prediction in both audio and text: ", num_pred_both)
# Out:
# Number of ordered sentences across all sessions:  10039
# Number of sentences that need prediction:  5531
# Number of sentences that need prediction in both audio and text:  3553

# %%
def match_features(index, order_audio_data):
    matched_features = {}
    if 'egemaps' not in order_audio_data[index]:
        print("Error occurred: No egemaps in the audio data, the index is ", index)
    else:
        egemaps = order_audio_data[index]['egemaps']
        column_names = egemaps.columns
        values = egemaps.values[0]
        for col_id in range(len(column_names)):
            matched_features[column_names[col_id]] = float(values[col_id])
        return matched_features

# %% [markdown]
# Step 3. Create an emotion predictor that takes context and spoken text as input and output an emotion label (what you need to modify).

# %%
def Gemini_emotion_predictor(context, cur_sentence, number_of_contexts, firstflag, audio2text):
    """
    Predicts the emotional state of a speaker based on the current input sentence and the conversational context.

    Parameters:
    context (list of dict): A list of dictionaries, each representing a previous conversational turn. Each dictionary
                            should contain at least the keys 'speaker' and 'sentence' indicating who the speaker was
                            and what they said, respectively.
    cur_input (dict): A dictionary representing the current sentence to be analyzed. It should contain at least the keys
                        'speaker' and 'sentence', similar to the dictionaries in `context`.
    number_of_contexts (int, optional): The number of contextual entries to consider for emotion prediction. Defaults to 3. The more context, the more expensive.

    Returns:
    str: The predicted emotion for the current sentence, from a set of predefined emotions such as 'happy', 'sad',
            'neutral', or 'angry'.
    """

    # for simplicity, we just use whisper-tiny's transcription, feel free to use any transcription we provide, and you can combine them
    background = 'Two speakers are talking. The conversation is:\n'
    if firstflag == False:
        context = '\n'.join(f"{item['speaker']}: {item['groundtruth']}" for item in context[-number_of_contexts:]) + '\n'
    else:
        context = '\n'.join(f"{item['speaker']}: {item['groundtruth']}" for item in context) + '\n'
    new_sentence = f"Now speaker {cur_sentence['speaker']} says: '{cur_sentence['groundtruth']}'. \n"
    if audio2text != "":
        audio = f"Here are 88 audio features of the current speaker's sentence, please find useful information from the features to finish a task. The features are: {audio2text}"
    else:
        audio = " "
    task = f"Task: Predict the probability of the emotion of the sentence '{cur_sentence['groundtruth']}' from the options [neutral, happy, angry, sad], consider the conversation context and audio features. Output satisfies the following rules.\n"
    task_req1 = "Rule 1: Generate a dictionary of emotion probabilities in format of {'neutral': 0.1, 'happy':0.0, 'angry':0.1, 'sad':0.8}. If you think there is only one emotion in the sentence, then give the probability to 1.\n "
    task_req2 = "Rule 2: Ensure the sum of probability equal to 1.\n"
    task_amb2 = "Rule 3: Do not explain, only need the dictionary.\n"
    task_final = "Please check again whether your output follows the three rules."
    prompt = background + context + new_sentence + audio + task + task_req1 + task_req2 + task_amb2 + task_final
    # print(prompt)
    response = model.generate_content(prompt)
    return response, prompt

# %%
R = model.generate_content("Generate a dictionary of emotion probabilities in format of {'neutral': 0.1, 'happy':0.0, 'angry':0.1, 'sad':0.8}. Do not explain, only the dictionary").text.strip()
R
# Out:
# I0000 00:00:1725144084.384070 7379571 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# I0000 00:00:1725144084.665959 8286562 subchannel.cc:806] subchannel 0x7f8ada4b2240 {address=ipv6:%5B2404:6800:4015:803::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8ada4a5f20, grpc.internal.security_connector=0x7f8ada48c6f0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T08:41:24.660761+10:00"}), backing off for 1000 ms
# "{'neutral': 0.1, 'happy': 0.0, 'angry': 0.1, 'sad': 0.8}"

# %%
# %%time
time.sleep(0.1)

cur_sentence = order_data[35]
audio2text = audio_features[35]
context = order_data[:35]
number_of_contexts = 3
firstflag = False
response, prompt = Gemini_emotion_predictor(context, cur_sentence, number_of_contexts, firstflag, audio2text)
print(response.text)
# Out:
# {'neutral': 0.0, 'happy': 0.0, 'angry': 0.0, 'sad': 1.0}
#
# CPU times: user 13.9 ms, sys: 5.64 ms, total: 19.5 ms
# Wall time: 841 ms

# %% [markdown]
# Step 4. Predict the entire session and output a sequence of emotion prediction for each sentence that requires a prediction.

# %%
# transfer response from ```json\n{'neutral': 0.0, 'happy': 0.0, 'angry': 0.0, 'sad': 1.0}\n```
def identify_format(text):
    match = re.search(r"\{.*\}", text)
    if match:
        text = match.group(0)
    result_dict = ast.literal_eval(text)
    return result_dict
def dictToList(dict, emo_labels):
    prob_list = [dict[emo] for emo in emo_labels]
    return prob_list

# %%
log = {}
def predict_sentence(index_sentence, number_of_contexts, data):
    error = False
    emo_labels = ['neutral', 'happy', 'angry', 'sad']
    cur_sentence = data[index_sentence]
    need_pred = cur_sentence['need_prediction']
     # if an emotion prediction is required for this sentence
    if index_sentence >= number_of_contexts:
        firstflag = False
        cur_context = data[index_sentence-number_of_contexts:index_sentence]
    else:
        firstflag = True
        cur_context = data[:index_sentence]
    cur_label = cur_sentence['emotion_probs']
    # context is all previous sentences in the conversation
    if "egemaps" in order_audio_data[index_sentence].keys():
        audio2text = match_features(index_sentence,order_audio_data)
    else:
        audio2text = ""
    try:
        time.sleep(0.1)
        response,prompt = Gemini_emotion_predictor(cur_context, cur_sentence, number_of_contexts, firstflag,audio2text)
        response = response.text.strip()
        # input both context and the current sentence to the emotion predictor
        try:
            clear_response = identify_format(response)
            cur_pred = dictToList(clear_response, emo_labels)
            log[cur_sentence["id"]] = [prompt, response]
        except:
            # if there is an error, fill a neutral to keep the output of same dimension
            print('Gemini response is not in the right format: ', response, cur_sentence['id'])
            cur_pred = [1.0,0.0,0.0,0.0]
            error = True
            log[cur_sentence["id"]] = ["Response not in the right format", prompt, response]
    except:
        print('Gemini api has an error.: ', cur_sentence)
        cur_pred = [1.0,0.0,0.0,0.0]
        error = True
        log[cur_sentence["id"]] = ["Gemini api has an error."]

    return cur_label, cur_pred, error

# %%
def make_predictions(number_context):
    number_errors, number_success = 0, 0
    started_sessions = []
    all_ground_truth, all_pred = [], []

    for i, item in enumerate(order_data):
        
        if item['id'][:-4] not in started_sessions:
            started_sessions.append(item['id'][:-4])
            print("Session ", item['id'][:-4])
            
        if item["need_prediction"] == "yes":
            label, prediction, error = predict_sentence(i, number_context, order_data)
            all_ground_truth.append(label)
            all_pred.append(prediction)
            if error == True:
                number_errors += 1
            else: 
                number_success += 1

        if i == len(order_data)-1 or order_data[i+1]['id'][:-4] != order_data[i]['id'][:-4]:
            print('Number of error counts:', number_errors, "; Number of predictions:", number_success)
            number_errors, number_success = 0, 0
            print('------------------------')
        # for testing
        # if i > 50:
        #     break
    return all_pred, all_ground_truth

# %%
def one_round(folder_path, number_context):

    all_pred, all_ground_truth = make_predictions(number_context)
    print("Total predictions: ", len(all_pred), "Total ground truth:", len(all_ground_truth))
    # Write to a CSV file using a context manager
    with open(f'./{folder_path}/pred.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(all_pred)

    with open(f'./{folder_path}/truth.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(all_ground_truth)

    json.dump(log, open(f'./{folder_path}/log.json', 'w'), indent=4)

# %%
one_round("prediction/0901_c20_audio", 20)
# Out:
# Session  Ses01F_impro01_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses01F_impro02_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses01F_impro03_
# Number of error counts: 0 ; Number of predictions: 41
# ------------------------
# Session  Ses01F_impro04_
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Session  Ses01F_impro05_
# Number of error counts: 0 ; Number of predictions: 22
# ------------------------
# Session  Ses01F_impro06_
# Number of error counts: 0 ; Number of predictions: 45
# ------------------------
# Session  Ses01F_impro07_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses01F_script01_1_
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Session  Ses01F_script01_2_
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Session  Ses01F_script01_3_
# I0000 00:00:1725146077.814397 8286570 subchannel.cc:806] subchannel 0x7f8b1b30f180 {address=ipv6:%5B2404:6800:4015:803::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30de40, grpc.internal.security_connector=0x7f8b1b30ebc0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:37.813942+10:00"}), backing off for 999 ms
# I0000 00:00:1725146078.071157 8286572 subchannel.cc:806] subchannel 0x7f8b1b311070 {address=ipv6:%5B2404:6800:4015:800::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30b540, grpc.internal.security_connector=0x7f8b1b310ab0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:38.070987+10:00"}), backing off for 999 ms
# I0000 00:00:1725146078.334071 8286563 subchannel.cc:806] subchannel 0x7f8b1b312f30 {address=ipv6:%5B2404:6800:4015:801::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b310d80, grpc.internal.security_connector=0x7f8b1b3129a0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:38.333655+10:00"}), backing off for 999 ms
# I0000 00:00:1725146078.595861 8286567 subchannel.cc:806] subchannel 0x7f8b1b314e10 {address=ipv6:%5B2404:6800:4015:802::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b313a20, grpc.internal.security_connector=0x7f8b1b314850, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:38.595554+10:00"}), backing off for 999 ms
# I0000 00:00:1725146078.816194 8286562 subchannel.cc:761] subchannel 0x7f8b1b30f180 {address=ipv6:%5B2404:6800:4015:803::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30de40, grpc.internal.security_connector=0x7f8b1b30ebc0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146079.071417 8286570 subchannel.cc:761] subchannel 0x7f8b1b311070 {address=ipv6:%5B2404:6800:4015:800::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30b540, grpc.internal.security_connector=0x7f8b1b310ab0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146079.339473 8286567 subchannel.cc:761] subchannel 0x7f8b1b312f30 {address=ipv6:%5B2404:6800:4015:801::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b310d80, grpc.internal.security_connector=0x7f8b1b3129a0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146079.600759 8286563 subchannel.cc:761] subchannel 0x7f8b1b314e10 {address=ipv6:%5B2404:6800:4015:802::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b313a20, grpc.internal.security_connector=0x7f8b1b314850, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146082.279527 8286572 subchannel.cc:806] subchannel 0x7f8b1b30f180 {address=ipv6:%5B2404:6800:4015:803::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30de40, grpc.internal.security_connector=0x7f8b1b30ebc0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:42.279115+10:00"}), backing off for 1661 ms
# I0000 00:00:1725146082.538048 8286570 subchannel.cc:806] subchannel 0x7f8b1b311070 {address=ipv6:%5B2404:6800:4015:800::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30b540, grpc.internal.security_connector=0x7f8b1b310ab0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:42.53775+10:00"}), backing off for 1739 ms
# I0000 00:00:1725146082.799901 8286562 subchannel.cc:806] subchannel 0x7f8b1b312f30 {address=ipv6:%5B2404:6800:4015:801::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b310d80, grpc.internal.security_connector=0x7f8b1b3129a0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:42.799488+10:00"}), backing off for 1548 ms
# I0000 00:00:1725146083.942129 8286568 subchannel.cc:761] subchannel 0x7f8b1b30f180 {address=ipv6:%5B2404:6800:4015:803::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30de40, grpc.internal.security_connector=0x7f8b1b30ebc0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146084.050507 8286566 subchannel.cc:806] subchannel 0x7f8b1b314e10 {address=ipv6:%5B2404:6800:4015:802::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b313a20, grpc.internal.security_connector=0x7f8b1b314850, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:44.050103+10:00"}), backing off for 1675 ms
# I0000 00:00:1725146084.286014 8286568 subchannel.cc:761] subchannel 0x7f8b1b311070 {address=ipv6:%5B2404:6800:4015:800::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30b540, grpc.internal.security_connector=0x7f8b1b310ab0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146084.349162 8286572 subchannel.cc:761] subchannel 0x7f8b1b312f30 {address=ipv6:%5B2404:6800:4015:801::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b310d80, grpc.internal.security_connector=0x7f8b1b3129a0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146084.796021 8286562 subchannel.cc:806] subchannel 0x7f8b1b30f180 {address=ipv6:%5B2404:6800:4015:803::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30de40, grpc.internal.security_connector=0x7f8b1b30ebc0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:44.795639+10:00"}), backing off for 2182 ms
# I0000 00:00:1725146085.056785 8286572 subchannel.cc:806] subchannel 0x7f8b1b311070 {address=ipv6:%5B2404:6800:4015:800::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30b540, grpc.internal.security_connector=0x7f8b1b310ab0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:45.056391+10:00"}), backing off for 2329 ms
# I0000 00:00:1725146085.318943 8286569 subchannel.cc:806] subchannel 0x7f8b1b312f30 {address=ipv6:%5B2404:6800:4015:801::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b310d80, grpc.internal.security_connector=0x7f8b1b3129a0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:45.31855+10:00"}), backing off for 2462 ms
# I0000 00:00:1725146085.736493 8286570 subchannel.cc:761] subchannel 0x7f8b1b314e10 {address=ipv6:%5B2404:6800:4015:802::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b313a20, grpc.internal.security_connector=0x7f8b1b314850, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146086.984079 8286565 subchannel.cc:761] subchannel 0x7f8b1b30f180 {address=ipv6:%5B2404:6800:4015:803::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30de40, grpc.internal.security_connector=0x7f8b1b30ebc0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146087.037169 8286571 subchannel.cc:806] subchannel 0x7f8b1b30f180 {address=ipv6:%5B2404:6800:4015:803::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30de40, grpc.internal.security_connector=0x7f8b1b30ebc0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:47.036741+10:00"}), backing off for 4532 ms
# I0000 00:00:1725146087.392540 8286570 subchannel.cc:761] subchannel 0x7f8b1b311070 {address=ipv6:%5B2404:6800:4015:800::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30b540, grpc.internal.security_connector=0x7f8b1b310ab0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146087.552368 8286569 subchannel.cc:806] subchannel 0x7f8b1b311070 {address=ipv6:%5B2404:6800:4015:800::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30b540, grpc.internal.security_connector=0x7f8b1b310ab0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:47.551957+10:00"}), backing off for 4060 ms
# I0000 00:00:1725146087.783391 8286565 subchannel.cc:761] subchannel 0x7f8b1b312f30 {address=ipv6:%5B2404:6800:4015:801::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b310d80, grpc.internal.security_connector=0x7f8b1b3129a0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146088.063522 8286572 subchannel.cc:806] subchannel 0x7f8b1b312f30 {address=ipv6:%5B2404:6800:4015:801::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b310d80, grpc.internal.security_connector=0x7f8b1b3129a0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:48.06339+10:00"}), backing off for 3410 ms
# I0000 00:00:1725146088.577398 8286571 subchannel.cc:806] subchannel 0x7f8b1b314e10 {address=ipv6:%5B2404:6800:4015:802::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b313a20, grpc.internal.security_connector=0x7f8b1b314850, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:48.576942+10:00"}), backing off for 2893 ms
# I0000 00:00:1725146091.481271 8286568 subchannel.cc:761] subchannel 0x7f8b1b312f30 {address=ipv6:%5B2404:6800:4015:801::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b310d80, grpc.internal.security_connector=0x7f8b1b3129a0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146091.481272 8286572 subchannel.cc:761] subchannel 0x7f8b1b314e10 {address=ipv6:%5B2404:6800:4015:802::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b313a20, grpc.internal.security_connector=0x7f8b1b314850, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146091.580307 8286567 subchannel.cc:761] subchannel 0x7f8b1b30f180 {address=ipv6:%5B2404:6800:4015:803::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30de40, grpc.internal.security_connector=0x7f8b1b30ebc0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146091.615556 8286572 subchannel.cc:761] subchannel 0x7f8b1b311070 {address=ipv6:%5B2404:6800:4015:800::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30b540, grpc.internal.security_connector=0x7f8b1b310ab0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146096.457067 8286566 subchannel.cc:806] subchannel 0x7f8b1b30f180 {address=ipv6:%5B2404:6800:4015:803::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30de40, grpc.internal.security_connector=0x7f8b1b30ebc0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:56.45661+10:00"}), backing off for 6345 ms
# I0000 00:00:1725146096.713507 8286565 subchannel.cc:806] subchannel 0x7f8b1b311070 {address=ipv6:%5B2404:6800:4015:800::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30b540, grpc.internal.security_connector=0x7f8b1b310ab0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:56.713237+10:00"}), backing off for 5935 ms
# I0000 00:00:1725146096.969592 8286563 subchannel.cc:806] subchannel 0x7f8b1b312f30 {address=ipv6:%5B2404:6800:4015:801::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b310d80, grpc.internal.security_connector=0x7f8b1b3129a0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:56.969291+10:00"}), backing off for 6443 ms
# I0000 00:00:1725146097.223804 8286569 subchannel.cc:806] subchannel 0x7f8b1b314e10 {address=ipv6:%5B2404:6800:4015:802::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b313a20, grpc.internal.security_connector=0x7f8b1b314850, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: No route to host (65) {created_time:"2024-09-01T09:14:57.223498+10:00"}), backing off for 4752 ms
# I0000 00:00:1725146097.555078 8286565 subchannel.cc:806] subchannel 0x7f8b1b30e250 {address=ipv4:142.250.70.202:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30b820, grpc.internal.security_connector=0x7f8b1b30dc90, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:tcp handshaker shutdown {created_time:"2024-09-01T09:14:57.554771+10:00"}), backing off for -19003 ms
# I0000 00:00:1725146097.555272 8286569 subchannel.cc:761] subchannel 0x7f8b1b30e250 {address=ipv4:142.250.70.202:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30b820, grpc.internal.security_connector=0x7f8b1b30dc90, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146097.816963 8286565 subchannel.cc:806] subchannel 0x7f8b1b3100e0 {address=ipv4:142.250.70.234:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30dba0, grpc.internal.security_connector=0x7f8b1b30fb00, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:tcp handshaker shutdown {created_time:"2024-09-01T09:14:57.81672+10:00"}), backing off for -19002 ms
# I0000 00:00:1725146097.817128 8286563 subchannel.cc:761] subchannel 0x7f8b1b3100e0 {address=ipv4:142.250.70.234:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30dba0, grpc.internal.security_connector=0x7f8b1b30fb00, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146098.076909 8286567 subchannel.cc:806] subchannel 0x7f8b1b311fd0 {address=ipv4:142.250.70.138:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30fcb0, grpc.internal.security_connector=0x7f8b1b3119f0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:tcp handshaker shutdown {created_time:"2024-09-01T09:14:58.07668+10:00"}), backing off for -19005 ms
# I0000 00:00:1725146098.077068 8286565 subchannel.cc:761] subchannel 0x7f8b1b311fd0 {address=ipv4:142.250.70.138:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30fcb0, grpc.internal.security_connector=0x7f8b1b3119f0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146098.335162 8286559 subchannel.cc:806] subchannel 0x7f8b1b313eb0 {address=ipv4:142.250.70.170:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b312ad0, grpc.internal.security_connector=0x7f8b1b3138f0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:Failed to connect to remote host: Timeout occurred: FD shutdown {created_time:"2024-09-01T09:14:58.334777+10:00", grpc_status:14, children:[UNKNOWN:connect() timed out {created_time:"2024-09-01T09:14:58.334642+10:00"}]}), backing off for -19000 ms
# I0000 00:00:1725146098.335313 8286563 subchannel.cc:761] subchannel 0x7f8b1b313eb0 {address=ipv4:142.250.70.170:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b312ad0, grpc.internal.security_connector=0x7f8b1b3138f0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146098.337281 8286559 subchannel.cc:806] subchannel 0x7f8b1b30e250 {address=ipv4:142.250.70.202:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30b820, grpc.internal.security_connector=0x7f8b1b30dc90, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: Network is unreachable (51) {created_time:"2024-09-01T09:14:58.335852+10:00"}), backing off for 1916 ms
# I0000 00:00:1725146098.337364 8286559 subchannel.cc:806] subchannel 0x7f8b1b3100e0 {address=ipv4:142.250.70.234:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30dba0, grpc.internal.security_connector=0x7f8b1b30fb00, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: Network is unreachable (51) {created_time:"2024-09-01T09:14:58.336245+10:00"}), backing off for 1852 ms
# I0000 00:00:1725146098.337425 8286559 subchannel.cc:806] subchannel 0x7f8b1b311fd0 {address=ipv4:142.250.70.138:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30fcb0, grpc.internal.security_connector=0x7f8b1b3119f0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: Network is unreachable (51) {created_time:"2024-09-01T09:14:58.336651+10:00"}), backing off for 1632 ms
# I0000 00:00:1725146098.337481 8286559 subchannel.cc:806] subchannel 0x7f8b1b313eb0 {address=ipv4:142.250.70.170:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b312ad0, grpc.internal.security_connector=0x7f8b1b3138f0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: Network is unreachable (51) {created_time:"2024-09-01T09:14:58.33698+10:00"}), backing off for 1533 ms
# I0000 00:00:1725146099.879129 8286567 subchannel.cc:761] subchannel 0x7f8b1b313eb0 {address=ipv4:142.250.70.170:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b312ad0, grpc.internal.security_connector=0x7f8b1b3138f0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146099.879994 8286567 subchannel.cc:806] subchannel 0x7f8b1b313eb0 {address=ipv4:142.250.70.170:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b312ad0, grpc.internal.security_connector=0x7f8b1b3138f0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: Network is unreachable (51) {created_time:"2024-09-01T09:14:59.879756+10:00"}), backing off for 3069 ms
# I0000 00:00:1725146099.978884 8286562 subchannel.cc:761] subchannel 0x7f8b1b311fd0 {address=ipv4:142.250.70.138:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30fcb0, grpc.internal.security_connector=0x7f8b1b3119f0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146099.979800 8286562 subchannel.cc:806] subchannel 0x7f8b1b311fd0 {address=ipv4:142.250.70.138:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30fcb0, grpc.internal.security_connector=0x7f8b1b3119f0, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: Network is unreachable (51) {created_time:"2024-09-01T09:14:59.979563+10:00"}), backing off for 2097 ms
# I0000 00:00:1725146100.200711 8286572 subchannel.cc:761] subchannel 0x7f8b1b3100e0 {address=ipv4:142.250.70.234:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30dba0, grpc.internal.security_connector=0x7f8b1b30fb00, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146100.201836 8286572 subchannel.cc:806] subchannel 0x7f8b1b3100e0 {address=ipv4:142.250.70.234:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30dba0, grpc.internal.security_connector=0x7f8b1b30fb00, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: Network is unreachable (51) {created_time:"2024-09-01T09:15:00.201512+10:00"}), backing off for 2815 ms
# I0000 00:00:1725146100.264504 8286568 subchannel.cc:761] subchannel 0x7f8b1b30e250 {address=ipv4:142.250.70.202:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30b820, grpc.internal.security_connector=0x7f8b1b30dc90, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# I0000 00:00:1725146100.265401 8286568 subchannel.cc:806] subchannel 0x7f8b1b30e250 {address=ipv4:142.250.70.202:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b30b820, grpc.internal.security_connector=0x7f8b1b30dc90, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: connect failed (UNKNOWN:connect: Network is unreachable (51) {created_time:"2024-09-01T09:15:00.265152+10:00"}), backing off for 2849 ms
# I0000 00:00:1725146101.979913 8286567 subchannel.cc:761] subchannel 0x7f8b1b314e10 {address=ipv6:%5B2404:6800:4015:802::200a%5D:443, args={grpc.client_channel_factory=0x7f8ada7c37f0, grpc.default_authority=generativelanguage.googleapis.com:443, grpc.dns_enable_srv_queries=1, grpc.http2_scheme=https, grpc.internal.channel_credentials=0x7f8b1b209860, grpc.internal.client_channel_call_destination=0x15366b1d8, grpc.internal.event_engine=0x7f8b1b313a20, grpc.internal.security_connector=0x7f8b1b314850, grpc.internal.subchannel_pool=0x7f8adbc36e90, grpc.max_receive_message_length=-1, grpc.max_send_message_length=-1, grpc.primary_user_agent=grpc-python/1.65.1, grpc.resource_quota=0x7f8b5a8d8c20, grpc.server_uri=dns:///generativelanguage.googleapis.com:443}}: backoff delay elapsed, reporting IDLE
# ...
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Session  Ses01M_script01_3_
# Gemini api has an error.:  {'id': 'Ses01M_script01_3_M032', 'emotion': ['Sadness', 'Sadness', 'Sadness'], 'need_prediction': 'yes', 'speaker': 'Ses013', 'groundtruth': "And I had this idea as I was watching them go down like everything was being destroyed, you know.  But I felt like this one new thing was being made, you know it's kind of like this.  This monument...", 'amb_emotion': ['sad', 'sad', 'sad'], 'emotion_probs': [0.0, 0.0, 0.0, 1.0]}
# Number of error counts: 1 ; Number of predictions: 53
# ------------------------
# Session  Ses01M_script02_1_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses01M_script02_2_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses01M_script03_1_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses01M_script03_2_
# Number of error counts: 0 ; Number of predictions: 41
# ------------------------
# Session  Ses02F_impro01_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses02F_impro02_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses02F_impro03_
# Number of error counts: 0 ; Number of predictions: 51
# ------------------------
# Session  Ses02F_impro04_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses02F_impro05_
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Session  Ses02F_impro06_
# Number of error counts: 0 ; Number of predictions: 33
# ------------------------
# Session  Ses02F_impro07_
# Number of error counts: 0 ; Number of predictions: 70
# ------------------------
# Session  Ses02F_impro08_
# Number of error counts: 0 ; Number of predictions: 41
# ------------------------
# Session  Ses02F_script01_1_
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Session  Ses02F_script01_2_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses02F_script01_3_
# Number of error counts: 0 ; Number of predictions: 39
# ------------------------
# Session  Ses02F_script02_1_
# Number of error counts: 0 ; Number of predictions: 28
# ------------------------
# Session  Ses02F_script02_2_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses02F_script03_1_
# Gemini api has an error.:  {'id': 'Ses02F_script03_1_M025', 'emotion': ['Happiness', 'Neutral state', 'Neutral state'], 'need_prediction': 'yes', 'speaker': 'Ses021', 'groundtruth': 'You remember that awful scene we had in Venice?', 'amb_emotion': ['hap', 'neu', 'neu'], 'emotion_probs': [0.67, 0.33, 0.0, 0.0]}
# Gemini api has an error.:  {'id': 'Ses02F_script03_1_F022', 'emotion': ['Happiness', 'Neutral state', 'Happiness'], 'need_prediction': 'yes', 'speaker': 'Ses021', 'groundtruth': 'Which particular one?', 'amb_emotion': ['hap', 'neu', 'hap'], 'emotion_probs': [0.33, 0.67, 0.0, 0.0]}
# Number of error counts: 2 ; Number of predictions: 50
# ------------------------
# Session  Ses02F_script03_2_
# Number of error counts: 0 ; Number of predictions: 20
# ------------------------
# Session  Ses02M_impro01_
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Session  Ses02M_impro02_
# Number of error counts: 0 ; Number of predictions: 13
# ------------------------
# Session  Ses02M_impro03_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses02M_impro04_
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Session  Ses02M_impro05_
# Number of error counts: 0 ; Number of predictions: 22
# ------------------------
# Session  Ses02M_impro06_
# Number of error counts: 0 ; Number of predictions: 40
# ------------------------
# Session  Ses02M_impro07_
# Number of error counts: 0 ; Number of predictions: 61
# ------------------------
# Session  Ses02M_impro08_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses02M_script01_1_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses02M_script01_2_
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Session  Ses02M_script01_3_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses02M_script02_1_
# Number of error counts: 0 ; Number of predictions: 24
# ------------------------
# Session  Ses02M_script02_2_
# Number of error counts: 0 ; Number of predictions: 33
# ------------------------
# Session  Ses02M_script03_1_
# Number of error counts: 0 ; Number of predictions: 39
# ------------------------
# Session  Ses02M_script03_2_
# Number of error counts: 0 ; Number of predictions: 25
# ------------------------
# Session  Ses03F_impro01_
# Number of error counts: 0 ; Number of predictions: 0
# ------------------------
# Session  Ses03F_impro02_
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Session  Ses03F_impro03_
# Number of error counts: 0 ; Number of predictions: 40
# ------------------------
# Session  Ses03F_impro04_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses03F_impro05_
# Number of error counts: 0 ; Number of predictions: 0
# ------------------------
# Session  Ses03F_impro06_
# Number of error counts: 0 ; Number of predictions: 53
# ------------------------
# Session  Ses03F_impro07_
# Number of error counts: 0 ; Number of predictions: 58
# ------------------------
# Session  Ses03F_impro08_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses03F_script01_1_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses03F_script01_2_
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Session  Ses03F_script01_3_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses03F_script02_1_
# Number of error counts: 0 ; Number of predictions: 23
# ------------------------
# Session  Ses03F_script02_2_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses03F_script03_1_
# Number of error counts: 0 ; Number of predictions: 45
# ------------------------
# Session  Ses03F_script03_2_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses03M_impro01_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses03M_impro02_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses03M_impro03_
# Number of error counts: 0 ; Number of predictions: 71
# ------------------------
# Session  Ses03M_impro04_
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Session  Ses03M_impro05a_
# Number of error counts: 0 ; Number of predictions: 22
# ------------------------
# Session  Ses03M_impro05b_
# Number of error counts: 0 ; Number of predictions: 28
# ------------------------
# Session  Ses03M_impro06_
# Number of error counts: 0 ; Number of predictions: 47
# ------------------------
# Session  Ses03M_impro07_
# Number of error counts: 0 ; Number of predictions: 46
# ------------------------
# Session  Ses03M_impro08a_
# Number of error counts: 0 ; Number of predictions: 13
# ------------------------
# Session  Ses03M_impro08b_
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Session  Ses03M_script01_1_
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Session  Ses03M_script01_2_
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Session  Ses03M_script01_3_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses03M_script02_1_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses03M_script02_2_
# Number of error counts: 0 ; Number of predictions: 33
# ------------------------
# Session  Ses03M_script03_1_
# Number of error counts: 0 ; Number of predictions: 58
# ------------------------
# Session  Ses03M_script03_2_
# Number of error counts: 0 ; Number of predictions: 24
# ------------------------
# Session  Ses04F_impro01_
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Session  Ses04F_impro02_
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Session  Ses04F_impro03_
# Number of error counts: 0 ; Number of predictions: 76
# ------------------------
# Session  Ses04F_impro04_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses04F_impro05_
# Number of error counts: 0 ; Number of predictions: 11
# ------------------------
# Session  Ses04F_impro06_
# Number of error counts: 0 ; Number of predictions: 23
# ------------------------
# Session  Ses04F_impro07_
# Number of error counts: 0 ; Number of predictions: 157
# ------------------------
# Session  Ses04F_impro08_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses04F_script01_1_
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Session  Ses04F_script01_2_
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Session  Ses04F_script01_3_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses04F_script02_1_
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Session  Ses04F_script02_2_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses04F_script03_1_
# Number of error counts: 0 ; Number of predictions: 53
# ------------------------
# Session  Ses04F_script03_2_
# Gemini api has an error.:  {'id': 'Ses04F_script03_2_F037', 'emotion': ['Anger', 'Anger', 'Anger'], 'need_prediction': 'yes', 'speaker': 'Ses042', 'groundtruth': "Listen? Listen indeed.  I'm sick and tired of listening to you.  You damn sadistic bully.", 'amb_emotion': ['ang', 'ang', 'ang'], 'emotion_probs': [0.0, 0.0, 1.0, 0.0]}
# Number of error counts: 1 ; Number of predictions: 20
# ------------------------
# Session  Ses04M_impro01_
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Session  Ses04M_impro02_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses04M_impro03_
# Number of error counts: 0 ; Number of predictions: 53
# ------------------------
# Session  Ses04M_impro04_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses04M_impro05_
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Session  Ses04M_impro06_
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Session  Ses04M_impro07_
# Number of error counts: 0 ; Number of predictions: 71
# ------------------------
# Session  Ses04M_impro08_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses04M_script01_1_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses04M_script01_2_
# Number of error counts: 0 ; Number of predictions: 19
# ------------------------
# Session  Ses04M_script01_3_
# Number of error counts: 0 ; Number of predictions: 28
# ------------------------
# Session  Ses04M_script02_1_
# Number of error counts: 0 ; Number of predictions: 19
# ------------------------
# Session  Ses04M_script02_2_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses04M_script03_1_
# Number of error counts: 0 ; Number of predictions: 44
# ------------------------
# Session  Ses04M_script03_2_
# Gemini api has an error.:  {'id': 'Ses04M_script03_2_F044', 'emotion': ['Anger', 'Anger', 'Anger'], 'need_prediction': 'yes', 'speaker': 'Ses042', 'groundtruth': 'Listen, indeed.  I am sick and tired of listening to you, you damn sadistic bully.', 'amb_emotion': ['ang', 'ang', 'ang'], 'emotion_probs': [0.0, 0.0, 1.0, 0.0]}
# Number of error counts: 1 ; Number of predictions: 44
# ------------------------
# Session  Ses05F_impro01_
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Session  Ses05F_impro02_
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Session  Ses05F_impro03_
# Number of error counts: 0 ; Number of predictions: 121
# ------------------------
# Session  Ses05F_impro04_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses05F_impro05_
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Session  Ses05F_impro06_
# Number of error counts: 0 ; Number of predictions: 52
# ------------------------
# Session  Ses05F_impro07_
# Number of error counts: 0 ; Number of predictions: 75
# ------------------------
# Session  Ses05F_impro08_
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Session  Ses05F_script01_1_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses05F_script01_2_
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Session  Ses05F_script01_3_
# Number of error counts: 0 ; Number of predictions: 41
# ------------------------
# Session  Ses05F_script02_1_
# Gemini api has an error.:  {'id': 'Ses05F_script02_1_M033', 'emotion': ['Happiness', 'Happiness', 'Happiness'], 'need_prediction': 'yes', 'speaker': 'Ses051', 'groundtruth': "They are swimming right now as if it's the only thing that matters.  It's- It's single mindedness with no mind, urgency that's pure urge. It's- They don't know what drives them.  They- They don't give any name or ask any question. They just turn as one and started to swim to the very point we are standing right now for a massive celebration of sex and death.  God, it's giving me goose bumps all over my hairs on my arm. popping up.", 'amb_emotion': ['hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0]}
# Number of error counts: 1 ; Number of predictions: 17
# ------------------------
# Session  Ses05F_script02_2_
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Session  Ses05F_script03_1_
# Number of error counts: 0 ; Number of predictions: 46
# ------------------------
# Session  Ses05F_script03_2_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses05M_impro01_
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Session  Ses05M_impro02_
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Session  Ses05M_impro03_
# Number of error counts: 0 ; Number of predictions: 58
# ------------------------
# Session  Ses05M_impro04_
# Number of error counts: 0 ; Number of predictions: 19
# ------------------------
# Session  Ses05M_impro05_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses05M_impro06_
# Number of error counts: 0 ; Number of predictions: 20
# ------------------------
# Session  Ses05M_impro07_
# Number of error counts: 0 ; Number of predictions: 90
# ------------------------
# Session  Ses05M_impro08_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses05M_script01_1_
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Session  Ses05M_script01_1b_
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Session  Ses05M_script01_2_
# Number of error counts: 0 ; Number of predictions: 13
# ------------------------
# Session  Ses05M_script01_3_
# Number of error counts: 0 ; Number of predictions: 32
# ------------------------
# Session  Ses05M_script02_1_
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Session  Ses05M_script02_2_
# Number of error counts: 0 ; Number of predictions: 32
# ------------------------
# Session  Ses05M_script03_1_
# Number of error counts: 0 ; Number of predictions: 60
# ------------------------
# Session  Ses05M_script03_2_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Total predictions:  4370 Total ground truth: 4370

# %%
one_round("prediction/0831_c10_audio", 10)
# Out:
# Session  Ses01F_impro01_
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725075558.388450 7379571 config.cc:230] gRPC experiments enabled: call_status_override_on_cancellation, event_engine_dns, event_engine_listener, http2_stats_fix, monitoring_experiment, pick_first_new, trace_record_callops, work_serializer_clears_time_cache
# I0000 00:00:1725075558.408557 7379571 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses01F_impro02_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses01F_impro03_
# Number of error counts: 0 ; Number of predictions: 41
# ------------------------
# Session  Ses01F_impro04_
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Session  Ses01F_impro05_
# Number of error counts: 0 ; Number of predictions: 22
# ------------------------
# Session  Ses01F_impro06_
# Number of error counts: 0 ; Number of predictions: 45
# ------------------------
# Session  Ses01F_impro07_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses01F_script01_1_
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Session  Ses01F_script01_2_
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Session  Ses01F_script01_3_
# Number of error counts: 0 ; Number of predictions: 51
# ------------------------
# Session  Ses01F_script02_1_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses01F_script02_2_
# Number of error counts: 0 ; Number of predictions: 34
# ------------------------
# Session  Ses01F_script03_1_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses01F_script03_2_
# Number of error counts: 0 ; Number of predictions: 28
# ------------------------
# Session  Ses01M_impro01_
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Session  Ses01M_impro02_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses01M_impro03_
# Number of error counts: 0 ; Number of predictions: 46
# ------------------------
# Session  Ses01M_impro04_
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Session  Ses01M_impro05_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses01M_impro06_
# Number of error counts: 0 ; Number of predictions: 59
# ------------------------
# Session  Ses01M_impro07_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses01M_script01_1_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses01M_script01_2_
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Session  Ses01M_script01_3_
# Number of error counts: 0 ; Number of predictions: 54
# ------------------------
# Session  Ses01M_script02_1_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses01M_script02_2_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses01M_script03_1_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses01M_script03_2_
# Number of error counts: 0 ; Number of predictions: 41
# ------------------------
# Session  Ses02F_impro01_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses02F_impro02_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses02F_impro03_
# Number of error counts: 0 ; Number of predictions: 51
# ------------------------
# Session  Ses02F_impro04_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses02F_impro05_
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Session  Ses02F_impro06_
# Number of error counts: 0 ; Number of predictions: 33
# ------------------------
# Session  Ses02F_impro07_
# Number of error counts: 0 ; Number of predictions: 70
# ------------------------
# Session  Ses02F_impro08_
# Number of error counts: 0 ; Number of predictions: 41
# ------------------------
# Session  Ses02F_script01_1_
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Session  Ses02F_script01_2_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses02F_script01_3_
# Number of error counts: 0 ; Number of predictions: 39
# ------------------------
# Session  Ses02F_script02_1_
# Number of error counts: 0 ; Number of predictions: 28
# ------------------------
# Session  Ses02F_script02_2_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses02F_script03_1_
# Number of error counts: 0 ; Number of predictions: 52
# ------------------------
# Session  Ses02F_script03_2_
# Number of error counts: 0 ; Number of predictions: 20
# ------------------------
# Session  Ses02M_impro01_
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Session  Ses02M_impro02_
# Number of error counts: 0 ; Number of predictions: 13
# ------------------------
# Session  Ses02M_impro03_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses02M_impro04_
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Session  Ses02M_impro05_
# Number of error counts: 0 ; Number of predictions: 22
# ------------------------
# Session  Ses02M_impro06_
# Number of error counts: 0 ; Number of predictions: 40
# ------------------------
# Session  Ses02M_impro07_
# Number of error counts: 0 ; Number of predictions: 61
# ------------------------
# Session  Ses02M_impro08_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses02M_script01_1_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses02M_script01_2_
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Session  Ses02M_script01_3_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses02M_script02_1_
# Number of error counts: 0 ; Number of predictions: 24
# ------------------------
# Session  Ses02M_script02_2_
# Number of error counts: 0 ; Number of predictions: 33
# ------------------------
# Session  Ses02M_script03_1_
# Number of error counts: 0 ; Number of predictions: 39
# ------------------------
# Session  Ses02M_script03_2_
# Number of error counts: 0 ; Number of predictions: 25
# ------------------------
# Session  Ses03F_impro01_
# Number of error counts: 0 ; Number of predictions: 0
# ------------------------
# Session  Ses03F_impro02_
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Session  Ses03F_impro03_
# Number of error counts: 0 ; Number of predictions: 40
# ------------------------
# Session  Ses03F_impro04_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses03F_impro05_
# Number of error counts: 0 ; Number of predictions: 0
# ------------------------
# Session  Ses03F_impro06_
# Number of error counts: 0 ; Number of predictions: 53
# ------------------------
# Session  Ses03F_impro07_
# Number of error counts: 0 ; Number of predictions: 58
# ------------------------
# Session  Ses03F_impro08_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses03F_script01_1_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses03F_script01_2_
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Session  Ses03F_script01_3_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses03F_script02_1_
# Number of error counts: 0 ; Number of predictions: 23
# ------------------------
# Session  Ses03F_script02_2_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses03F_script03_1_
# Number of error counts: 0 ; Number of predictions: 45
# ------------------------
# Session  Ses03F_script03_2_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses03M_impro01_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses03M_impro02_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses03M_impro03_
# Number of error counts: 0 ; Number of predictions: 71
# ------------------------
# Session  Ses03M_impro04_
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Session  Ses03M_impro05a_
# Number of error counts: 0 ; Number of predictions: 22
# ------------------------
# Session  Ses03M_impro05b_
# Number of error counts: 0 ; Number of predictions: 28
# ------------------------
# Session  Ses03M_impro06_
# Number of error counts: 0 ; Number of predictions: 47
# ------------------------
# Session  Ses03M_impro07_
# Number of error counts: 0 ; Number of predictions: 46
# ------------------------
# Session  Ses03M_impro08a_
# Number of error counts: 0 ; Number of predictions: 13
# ------------------------
# Session  Ses03M_impro08b_
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Session  Ses03M_script01_1_
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Session  Ses03M_script01_2_
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Session  Ses03M_script01_3_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses03M_script02_1_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses03M_script02_2_
# Number of error counts: 0 ; Number of predictions: 33
# ------------------------
# Session  Ses03M_script03_1_
# Number of error counts: 0 ; Number of predictions: 58
# ------------------------
# Session  Ses03M_script03_2_
# Number of error counts: 0 ; Number of predictions: 24
# ------------------------
# Session  Ses04F_impro01_
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Session  Ses04F_impro02_
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Session  Ses04F_impro03_
# Number of error counts: 0 ; Number of predictions: 76
# ------------------------
# Session  Ses04F_impro04_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses04F_impro05_
# Number of error counts: 0 ; Number of predictions: 11
# ------------------------
# Session  Ses04F_impro06_
# Number of error counts: 0 ; Number of predictions: 23
# ------------------------
# Session  Ses04F_impro07_
# Number of error counts: 0 ; Number of predictions: 157
# ------------------------
# Session  Ses04F_impro08_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses04F_script01_1_
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Session  Ses04F_script01_2_
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Session  Ses04F_script01_3_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses04F_script02_1_
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Session  Ses04F_script02_2_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses04F_script03_1_
# Number of error counts: 0 ; Number of predictions: 53
# ------------------------
# Session  Ses04F_script03_2_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses04M_impro01_
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Session  Ses04M_impro02_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses04M_impro03_
# Number of error counts: 0 ; Number of predictions: 53
# ------------------------
# Session  Ses04M_impro04_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses04M_impro05_
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Session  Ses04M_impro06_
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Session  Ses04M_impro07_
# Number of error counts: 0 ; Number of predictions: 71
# ------------------------
# Session  Ses04M_impro08_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses04M_script01_1_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses04M_script01_2_
# Number of error counts: 0 ; Number of predictions: 19
# ------------------------
# Session  Ses04M_script01_3_
# Number of error counts: 0 ; Number of predictions: 28
# ------------------------
# Session  Ses04M_script02_1_
# Number of error counts: 0 ; Number of predictions: 19
# ------------------------
# Session  Ses04M_script02_2_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses04M_script03_1_
# Number of error counts: 0 ; Number of predictions: 44
# ------------------------
# Session  Ses04M_script03_2_
# Number of error counts: 0 ; Number of predictions: 45
# ------------------------
# Session  Ses05F_impro01_
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Session  Ses05F_impro02_
# Gemini api has an error.:  {'id': 'Ses05F_impro02_M015', 'emotion': ['Anger', 'Anger', 'Anger'], 'need_prediction': 'yes', 'speaker': 'Ses05M', 'groundtruth': "It doesn't make any sense.  It's stupid.  I told you you shouldn't go in the Army.", 'audio': 'IEMOCAP_full_release/Session/5/sentences/wav/Ses05F_impro02_M015/Ses05F_impro02_M015.wav', 'amb_emotion': ['ang', 'ang', 'ang'], 'emotion_probs': [0.0, 0.0, 1.0, 0.0]}
# Number of error counts: 1 ; Number of predictions: 13
# ------------------------
# Session  Ses05F_impro03_
# Number of error counts: 0 ; Number of predictions: 121
# ------------------------
# Session  Ses05F_impro04_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses05F_impro05_
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Session  Ses05F_impro06_
# Number of error counts: 0 ; Number of predictions: 52
# ------------------------
# Session  Ses05F_impro07_
# Number of error counts: 0 ; Number of predictions: 75
# ------------------------
# Session  Ses05F_impro08_
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Session  Ses05F_script01_1_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses05F_script01_2_
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Session  Ses05F_script01_3_
# Number of error counts: 0 ; Number of predictions: 41
# ------------------------
# Session  Ses05F_script02_1_
# Gemini api has an error.:  {'id': 'Ses05F_script02_1_M033', 'emotion': ['Happiness', 'Happiness', 'Happiness'], 'need_prediction': 'yes', 'speaker': 'Ses051', 'groundtruth': "They are swimming right now as if it's the only thing that matters.  It's- It's single mindedness with no mind, urgency that's pure urge. It's- They don't know what drives them.  They- They don't give any name or ask any question. They just turn as one and started to swim to the very point we are standing right now for a massive celebration of sex and death.  God, it's giving me goose bumps all over my hairs on my arm. popping up.", 'amb_emotion': ['hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0]}
# Number of error counts: 1 ; Number of predictions: 17
# ------------------------
# Session  Ses05F_script02_2_
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Session  Ses05F_script03_1_
# Number of error counts: 0 ; Number of predictions: 46
# ------------------------
# Session  Ses05F_script03_2_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses05M_impro01_
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Session  Ses05M_impro02_
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Session  Ses05M_impro03_
# Number of error counts: 0 ; Number of predictions: 58
# ------------------------
# Session  Ses05M_impro04_
# Number of error counts: 0 ; Number of predictions: 19
# ------------------------
# Session  Ses05M_impro05_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses05M_impro06_
# Number of error counts: 0 ; Number of predictions: 20
# ------------------------
# Session  Ses05M_impro07_
# Number of error counts: 0 ; Number of predictions: 90
# ------------------------
# Session  Ses05M_impro08_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses05M_script01_1_
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Session  Ses05M_script01_1b_
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Session  Ses05M_script01_2_
# Number of error counts: 0 ; Number of predictions: 13
# ------------------------
# Session  Ses05M_script01_3_
# Number of error counts: 0 ; Number of predictions: 32
# ------------------------
# Session  Ses05M_script02_1_
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Session  Ses05M_script02_2_
# Number of error counts: 0 ; Number of predictions: 32
# ------------------------
# Session  Ses05M_script03_1_
# Number of error counts: 0 ; Number of predictions: 60
# ------------------------
# Session  Ses05M_script03_2_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Total predictions:  4370 Total ground truth: 4370

# %%
one_round("prediction/0830_c5_audio" , 5)
# Out:
# Session  Ses01F_impro01_
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725001019.312325 6761064 config.cc:230] gRPC experiments enabled: call_status_override_on_cancellation, event_engine_dns, event_engine_listener, http2_stats_fix, monitoring_experiment, pick_first_new, trace_record_callops, work_serializer_clears_time_cache
# I0000 00:00:1725001019.323614 6761064 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses01F_impro02_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses01F_impro03_
# Number of error counts: 0 ; Number of predictions: 41
# ------------------------
# Session  Ses01F_impro04_
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Session  Ses01F_impro05_
# Number of error counts: 0 ; Number of predictions: 22
# ------------------------
# Session  Ses01F_impro06_
# Number of error counts: 0 ; Number of predictions: 45
# ------------------------
# Session  Ses01F_impro07_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses01F_script01_1_
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Session  Ses01F_script01_2_
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Session  Ses01F_script01_3_
# Number of error counts: 0 ; Number of predictions: 51
# ------------------------
# Session  Ses01F_script02_1_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses01F_script02_2_
# Number of error counts: 0 ; Number of predictions: 34
# ------------------------
# Session  Ses01F_script03_1_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses01F_script03_2_
# Number of error counts: 0 ; Number of predictions: 28
# ------------------------
# Session  Ses01M_impro01_
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Session  Ses01M_impro02_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses01M_impro03_
# Number of error counts: 0 ; Number of predictions: 46
# ------------------------
# Session  Ses01M_impro04_
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Session  Ses01M_impro05_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses01M_impro06_
# Number of error counts: 0 ; Number of predictions: 59
# ------------------------
# Session  Ses01M_impro07_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses01M_script01_1_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses01M_script01_2_
# Number of error counts: 0 ; Number of predictions: 5
# ------------------------
# Session  Ses01M_script01_3_
# Number of error counts: 0 ; Number of predictions: 54
# ------------------------
# Session  Ses01M_script02_1_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses01M_script02_2_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses01M_script03_1_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses01M_script03_2_
# Number of error counts: 0 ; Number of predictions: 41
# ------------------------
# Session  Ses02F_impro01_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses02F_impro02_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses02F_impro03_
# Number of error counts: 0 ; Number of predictions: 51
# ------------------------
# Session  Ses02F_impro04_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses02F_impro05_
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Session  Ses02F_impro06_
# Number of error counts: 0 ; Number of predictions: 33
# ------------------------
# Session  Ses02F_impro07_
# Number of error counts: 0 ; Number of predictions: 70
# ------------------------
# Session  Ses02F_impro08_
# Number of error counts: 0 ; Number of predictions: 41
# ------------------------
# Session  Ses02F_script01_1_
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Session  Ses02F_script01_2_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses02F_script01_3_
# Number of error counts: 0 ; Number of predictions: 39
# ------------------------
# Session  Ses02F_script02_1_
# Number of error counts: 0 ; Number of predictions: 28
# ------------------------
# Session  Ses02F_script02_2_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses02F_script03_1_
# Number of error counts: 0 ; Number of predictions: 52
# ------------------------
# Session  Ses02F_script03_2_
# Number of error counts: 0 ; Number of predictions: 20
# ------------------------
# Session  Ses02M_impro01_
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Session  Ses02M_impro02_
# Number of error counts: 0 ; Number of predictions: 13
# ------------------------
# Session  Ses02M_impro03_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses02M_impro04_
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Session  Ses02M_impro05_
# Number of error counts: 0 ; Number of predictions: 22
# ------------------------
# Session  Ses02M_impro06_
# Number of error counts: 0 ; Number of predictions: 40
# ------------------------
# Session  Ses02M_impro07_
# Number of error counts: 0 ; Number of predictions: 61
# ------------------------
# Session  Ses02M_impro08_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses02M_script01_1_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses02M_script01_2_
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Session  Ses02M_script01_3_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses02M_script02_1_
# Number of error counts: 0 ; Number of predictions: 24
# ------------------------
# Session  Ses02M_script02_2_
# Number of error counts: 0 ; Number of predictions: 33
# ------------------------
# Session  Ses02M_script03_1_
# Number of error counts: 0 ; Number of predictions: 39
# ------------------------
# Session  Ses02M_script03_2_
# Number of error counts: 0 ; Number of predictions: 25
# ------------------------
# Session  Ses03F_impro01_
# Number of error counts: 0 ; Number of predictions: 0
# ------------------------
# Session  Ses03F_impro02_
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Session  Ses03F_impro03_
# Number of error counts: 0 ; Number of predictions: 40
# ------------------------
# Session  Ses03F_impro04_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses03F_impro05_
# Number of error counts: 0 ; Number of predictions: 0
# ------------------------
# Session  Ses03F_impro06_
# Number of error counts: 0 ; Number of predictions: 53
# ------------------------
# Session  Ses03F_impro07_
# Number of error counts: 0 ; Number of predictions: 58
# ------------------------
# Session  Ses03F_impro08_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses03F_script01_1_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses03F_script01_2_
# Number of error counts: 0 ; Number of predictions: 12
# ------------------------
# Session  Ses03F_script01_3_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses03F_script02_1_
# Number of error counts: 0 ; Number of predictions: 23
# ------------------------
# Session  Ses03F_script02_2_
# Number of error counts: 0 ; Number of predictions: 36
# ------------------------
# Session  Ses03F_script03_1_
# Number of error counts: 0 ; Number of predictions: 45
# ------------------------
# Session  Ses03F_script03_2_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses03M_impro01_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses03M_impro02_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses03M_impro03_
# Number of error counts: 0 ; Number of predictions: 71
# ------------------------
# Session  Ses03M_impro04_
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Session  Ses03M_impro05a_
# Number of error counts: 0 ; Number of predictions: 22
# ------------------------
# Session  Ses03M_impro05b_
# Number of error counts: 0 ; Number of predictions: 28
# ------------------------
# Session  Ses03M_impro06_
# Number of error counts: 0 ; Number of predictions: 47
# ------------------------
# Session  Ses03M_impro07_
# Number of error counts: 0 ; Number of predictions: 46
# ------------------------
# Session  Ses03M_impro08a_
# Number of error counts: 0 ; Number of predictions: 13
# ------------------------
# Session  Ses03M_impro08b_
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Session  Ses03M_script01_1_
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Session  Ses03M_script01_2_
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Session  Ses03M_script01_3_
# Number of error counts: 0 ; Number of predictions: 50
# ------------------------
# Session  Ses03M_script02_1_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses03M_script02_2_
# Number of error counts: 0 ; Number of predictions: 33
# ------------------------
# Session  Ses03M_script03_1_
# Number of error counts: 0 ; Number of predictions: 58
# ------------------------
# Session  Ses03M_script03_2_
# Number of error counts: 0 ; Number of predictions: 24
# ------------------------
# Session  Ses04F_impro01_
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Session  Ses04F_impro02_
# Number of error counts: 0 ; Number of predictions: 6
# ------------------------
# Session  Ses04F_impro03_
# Number of error counts: 0 ; Number of predictions: 76
# ------------------------
# Session  Ses04F_impro04_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses04F_impro05_
# Number of error counts: 0 ; Number of predictions: 11
# ------------------------
# Session  Ses04F_impro06_
# Number of error counts: 0 ; Number of predictions: 23
# ------------------------
# Session  Ses04F_impro07_
# Number of error counts: 0 ; Number of predictions: 157
# ------------------------
# Session  Ses04F_impro08_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses04F_script01_1_
# Number of error counts: 0 ; Number of predictions: 14
# ------------------------
# Session  Ses04F_script01_2_
# Number of error counts: 0 ; Number of predictions: 4
# ------------------------
# Session  Ses04F_script01_3_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses04F_script02_1_
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Session  Ses04F_script02_2_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Session  Ses04F_script03_1_
# Number of error counts: 0 ; Number of predictions: 53
# ------------------------
# Session  Ses04F_script03_2_
# Gemini api has an error.:  {'id': 'Ses04F_script03_2_F037', 'emotion': ['Anger', 'Anger', 'Anger'], 'need_prediction': 'yes', 'speaker': 'Ses042', 'groundtruth': "Listen? Listen indeed.  I'm sick and tired of listening to you.  You damn sadistic bully.", 'amb_emotion': ['ang', 'ang', 'ang'], 'emotion_probs': [0.0, 0.0, 1.0, 0.0]}
# Number of error counts: 1 ; Number of predictions: 20
# ------------------------
# Session  Ses04M_impro01_
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Session  Ses04M_impro02_
# Number of error counts: 0 ; Number of predictions: 2
# ------------------------
# Session  Ses04M_impro03_
# Number of error counts: 0 ; Number of predictions: 53
# ------------------------
# Session  Ses04M_impro04_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses04M_impro05_
# Number of error counts: 0 ; Number of predictions: 9
# ------------------------
# Session  Ses04M_impro06_
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Session  Ses04M_impro07_
# Number of error counts: 0 ; Number of predictions: 71
# ------------------------
# Session  Ses04M_impro08_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses04M_script01_1_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses04M_script01_2_
# Number of error counts: 0 ; Number of predictions: 19
# ------------------------
# Session  Ses04M_script01_3_
# Number of error counts: 0 ; Number of predictions: 28
# ------------------------
# Session  Ses04M_script02_1_
# Gemini api has an error.:  {'id': 'Ses04M_script02_1_M032', 'emotion': ['Happiness', 'Happiness', 'Happiness'], 'need_prediction': 'yes', 'speaker': 'Ses041', 'groundtruth': "They don't know what drives them.  They don't give it a name or ask a question.  They just turn, as one, and start the swim that brings them here; to this place, where we stand, for a massive celebration of sex and death.  Oh, man, I'm giving myself goose bumps.  All my hairs are popping up.", 'amb_emotion': ['hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0]}
# Number of error counts: 1 ; Number of predictions: 18
# ------------------------
# Session  Ses04M_script02_2_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses04M_script03_1_
# Number of error counts: 0 ; Number of predictions: 44
# ------------------------
# Session  Ses04M_script03_2_
# Gemini api has an error.:  {'id': 'Ses04M_script03_2_F044', 'emotion': ['Anger', 'Anger', 'Anger'], 'need_prediction': 'yes', 'speaker': 'Ses042', 'groundtruth': 'Listen, indeed.  I am sick and tired of listening to you, you damn sadistic bully.', 'amb_emotion': ['ang', 'ang', 'ang'], 'emotion_probs': [0.0, 0.0, 1.0, 0.0]}
# Number of error counts: 1 ; Number of predictions: 44
# ------------------------
# Session  Ses05F_impro01_
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Session  Ses05F_impro02_
# Gemini api has an error.:  {'id': 'Ses05F_impro02_M015', 'emotion': ['Anger', 'Anger', 'Anger'], 'need_prediction': 'yes', 'speaker': 'Ses05M', 'groundtruth': "It doesn't make any sense.  It's stupid.  I told you you shouldn't go in the Army.", 'audio': 'IEMOCAP_full_release/Session/5/sentences/wav/Ses05F_impro02_M015/Ses05F_impro02_M015.wav', 'amb_emotion': ['ang', 'ang', 'ang'], 'emotion_probs': [0.0, 0.0, 1.0, 0.0]}
# Number of error counts: 1 ; Number of predictions: 13
# ------------------------
# Session  Ses05F_impro03_
# Number of error counts: 0 ; Number of predictions: 121
# ------------------------
# Session  Ses05F_impro04_
# Number of error counts: 0 ; Number of predictions: 21
# ------------------------
# Session  Ses05F_impro05_
# Number of error counts: 0 ; Number of predictions: 16
# ------------------------
# Session  Ses05F_impro06_
# Number of error counts: 0 ; Number of predictions: 52
# ------------------------
# Session  Ses05F_impro07_
# Number of error counts: 0 ; Number of predictions: 75
# ------------------------
# Session  Ses05F_impro08_
# Number of error counts: 0 ; Number of predictions: 30
# ------------------------
# Session  Ses05F_script01_1_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses05F_script01_2_
# Number of error counts: 0 ; Number of predictions: 3
# ------------------------
# Session  Ses05F_script01_3_
# Number of error counts: 0 ; Number of predictions: 41
# ------------------------
# Session  Ses05F_script02_1_
# Number of error counts: 0 ; Number of predictions: 18
# ------------------------
# Session  Ses05F_script02_2_
# Number of error counts: 0 ; Number of predictions: 26
# ------------------------
# Session  Ses05F_script03_1_
# Number of error counts: 0 ; Number of predictions: 46
# ------------------------
# Session  Ses05F_script03_2_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses05M_impro01_
# Number of error counts: 0 ; Number of predictions: 1
# ------------------------
# Session  Ses05M_impro02_
# Number of error counts: 0 ; Number of predictions: 15
# ------------------------
# Session  Ses05M_impro03_
# Number of error counts: 0 ; Number of predictions: 58
# ------------------------
# Session  Ses05M_impro04_
# Number of error counts: 0 ; Number of predictions: 19
# ------------------------
# Session  Ses05M_impro05_
# Number of error counts: 0 ; Number of predictions: 10
# ------------------------
# Session  Ses05M_impro06_
# Number of error counts: 0 ; Number of predictions: 20
# ------------------------
# Session  Ses05M_impro07_
# Number of error counts: 0 ; Number of predictions: 90
# ------------------------
# Session  Ses05M_impro08_
# Number of error counts: 0 ; Number of predictions: 37
# ------------------------
# Session  Ses05M_script01_1_
# Number of error counts: 0 ; Number of predictions: 8
# ------------------------
# Session  Ses05M_script01_1b_
# Number of error counts: 0 ; Number of predictions: 7
# ------------------------
# Session  Ses05M_script01_2_
# Number of error counts: 0 ; Number of predictions: 13
# ------------------------
# Session  Ses05M_script01_3_
# Number of error counts: 0 ; Number of predictions: 32
# ------------------------
# Session  Ses05M_script02_1_
# Gemini api has an error.:  {'id': 'Ses05M_script02_1_M032', 'emotion': ['Happiness', 'Happiness', 'Happiness'], 'need_prediction': 'yes', 'speaker': 'Ses051', 'groundtruth': "they just all as one turn around and start swimming to this very point where we are standing now for one last celebration of sex and death. God, it's giving me Goosebumps.  Look at all the hairs that are standing up.", 'amb_emotion': ['hap', 'hap', 'hap'], 'emotion_probs': [0.0, 1.0, 0.0, 0.0]}
# Number of error counts: 1 ; Number of predictions: 15
# ------------------------
# Session  Ses05M_script02_2_
# Number of error counts: 0 ; Number of predictions: 32
# ------------------------
# Session  Ses05M_script03_1_
# Number of error counts: 0 ; Number of predictions: 60
# ------------------------
# Session  Ses05M_script03_2_
# Number of error counts: 0 ; Number of predictions: 27
# ------------------------
# Total predictions:  4370 Total ground truth: 4370

# %%
one_round("prediction/0828_c2_audio_4370", 5)

# %%
one_round("prediction/0827_c5_audio_v1", 5)

# %% [markdown]
# Error Analysis
